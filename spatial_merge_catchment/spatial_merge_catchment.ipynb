# %% [markdown]
# # 1. Imports and load data

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon, MultiPolygon
import sqlite3
import folium

# %% [markdown]
# ## walk zones:

# %%
with sqlite3.connect('../database.db') as conn:
    df_wz = pd.read_sql_query('''
                                   SELECT s.school_id, s.name, wz.polygon_number, wz.lat_coordinate, wz.long_coordinate
FROM walk_zones wz
INNER JOIN schools s on s.school_id = wz.school_id
                                   ''', conn)

# %%
df_wz.head(2)
# Out:
#    school_id                name  polygon_number  lat_coordinate  \
# 0        142  A. E. Cross School               0       51.017392
# 1        142  A. E. Cross School               0       51.020302
#
#    long_coordinate
# 0      -114.117939
# 1      -114.117945

# %% [markdown]
# ### Testing .dissolve function:

# %%
gdf_wz_d = gpd.GeoDataFrame(df_wz,geometry = gpd.points_from_xy(df_wz['long_coordinate'], df_wz['lat_coordinate'], crs="EPSG:4326"))

# %%
gdf_wz_d.head()
# Out:
#    school_id                name  polygon_number  lat_coordinate  \
# 0        142  A. E. Cross School               0       51.017392
# 1        142  A. E. Cross School               0       51.020302
# 2        142  A. E. Cross School               0       51.021632
# 3        142  A. E. Cross School               0       51.022792
# 4        142  A. E. Cross School               0       51.023261
#
#    long_coordinate                     geometry
# 0      -114.117939  POINT (-114.11794 51.01739)
# 1      -114.117945  POINT (-114.11794 51.02030)
# 2      -114.117947  POINT (-114.11795 51.02163)
# 3      -114.117949  POINT (-114.11795 51.02279)
# 4      -114.117932  POINT (-114.11793 51.02326)

# %%
gdf_wz_dis= gdf_wz_d.dissolve(by=['school_id','name','polygon_number'])

# %%
gdf_wz_dis.head(3)
# Out:
#                                                                                              geometry  \
# school_id name                      polygon_number
# 6         Richmond School           0               MULTIPOINT ((-114.13126 51.02814), (-114.13126...
# 7         Alexander Ferguson School 0               MULTIPOINT ((-114.12274 51.04907), (-114.12270...
#                                     1               MULTIPOINT ((-114.13550 51.03471), (-114.13550...
#
#                                                     lat_coordinate  \
# school_id name                      polygon_number
# 6         Richmond School           0                    51.037837
# 7         Alexander Ferguson School 0                    51.049070
#                                     1                    51.049070
#
#                                                     long_coordinate
# school_id name                      polygon_number
# 6         Richmond School           0                   -114.111247
# 7         Alexander Ferguson School 0                   -114.122735
#                                     1                   -114.122735

# %%
gdf_wz_dis2 = gdf_wz_dis.dissolve(by=['school_id','name'])

# %%
gdf_wz_dis2.head(3)
# Out:
#                                                                               geometry  \
# school_id name
# 6         Richmond School            MULTIPOINT ((-114.13126 51.02814), (-114.13126...
# 7         Alexander Ferguson School  MULTIPOINT ((-114.13550 51.03471), (-114.13550...
# 8         Jennie Elliott School      MULTIPOINT ((-114.14130 51.00431), (-114.14130...
#
#                                      lat_coordinate  long_coordinate
# school_id name
# 6         Richmond School                 51.037837      -114.111247
# 7         Alexander Ferguson School       51.049070      -114.122735
# 8         Jennie Elliott School           51.005794      -114.134527

# %% [markdown]
# ### adjusting the transform function using dissolve()

# %%
def transform_to_geometry_test(df):
    """
    Transform a DataFrame with individual coordinate points into a GeoDataFrame with polygon geometries.
    
    This function takes a DataFrame that includes school IDs, names, polygon numbers, and pairs
    of latitude and longitude coordinates. It groups the points by school and polygon number to
    create polygons, and then creates a MultiPolygon for schools with multiple polygons.
    The resulting GeoDataFrame has one row per school with a geometry column containing the 
    corresponding MultiPolygon or Polygon.
    
    Parameters:
    - df (pd.DataFrame): A DataFrame with the following columns:
        - 'school_id': An identifier for the school.
        - 'name': The name of the school.
        - 'polygon_number': An identifier for a polygon (in case a school has multiple polygons).
        - 'long_coordinate': Longitude part of the coordinate.
        - 'lat_coordinate': Latitude part of the coordinate.
        
    Returns:
    - gpd.GeoDataFrame: A GeoDataFrame with the following columns:
        - 'school_id': An identifier for the school.
        - 'name': The name of the school.
        - 'geometry': A shapely.geometry.Polygon or shapely.geometry.MultiPolygon object representing the school's geometry.
    """
    
    # First, create a new DataFrame for polygons
    df_polygons = df.groupby(['school_id', 'name', 'polygon_number']).apply(
        lambda group: Polygon(zip(group['long_coordinate'], group['lat_coordinate']))
    ).reset_index().rename(columns={0: 'geometry'})
    
    # Convert our DataFrame with Polygon objects into a GeoDataFrame
    gdf_polygons = gpd.GeoDataFrame(df_polygons, geometry='geometry',crs="EPSG:4326")
    
    # Now use dissolve to merge the polygons into MultiPolygons where necessary
    gdf = gdf_polygons.dissolve(by=['school_id', 'name'], as_index=False)
    
    # Ensure the geometry column contains only MultiPolygon instances
    #gdf['geometry'] = gdf.apply(lambda row: MultiPolygon([row.geometry]) if type(row.geometry) is Polygon else row.geometry, axis=1)

    gdf.drop(columns = ['polygon_number'],inplace=True)
    return gdf

# %%
df_wz_test= transform_to_geometry_test(df_wz)

# %%
df_wz_test.head(10)
# Out:
#    school_id                       name  \
# 0          6            Richmond School
# 1          7  Alexander Ferguson School
# 2          8      Jennie Elliott School
# 3          9           Killarney School
# 4         11            Altadore School
# 5         12   Belvedere Parkway School
# 6         13            Bowcroft School
# 7         14           Connaught School
# 8         15           Earl Grey School
# 9         16          Elbow Park School
#
#                                             geometry
# 0  POLYGON ((-114.11125 51.03784, -114.11326 51.0...
# 1  MULTIPOLYGON (((-114.12279 51.04906, -114.1228...
# 2  POLYGON ((-114.13453 51.00579, -114.13608 51.0...
# 3  POLYGON ((-114.14115 51.01245, -114.13875 51.0...
# 4  POLYGON ((-114.09209 51.01611, -114.09205 51.0...
# 5  POLYGON ((-114.22291 51.09864, -114.22302 51.0...
# 6  POLYGON ((-114.19730 51.09800, -114.19734 51.0...
# 7  POLYGON ((-114.07151 51.04419, -114.07152 51.0...
# 8  POLYGON ((-114.07830 51.03781, -114.07936 51.0...
# 9  POLYGON ((-114.07730 51.02642, -114.07797 51.0...

# %%
df_wz_test.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   school_id  237 non-null    int64
#  1   name       237 non-null    object
#  2   geometry   237 non-null    geometry
# dtypes: geometry(1), int64(1), object(1)
# memory usage: 5.7+ KB

# %% [markdown]
# #### export to GeoJSON to Tableau

# %%
df_wz_test.reset_index(inplace=True)
df_wz_test["row_id"] = df_wz_test.index + 1
df_wz_test.reset_index(drop=True, inplace=True)
df_wz_test.set_index("row_id", inplace = True)

# %%
df_wz_test.to_file('walk_zones.geojson', driver='GeoJSON')

# %% [markdown]
# #### Continue

# %%
id_interest = [7, 31, 129, 146, 167, 173, 174, 182, 184, 201, 226, 15486]
df_wz_test_filtered = df_wz_test[df_wz_test['school_id'].isin(id_interest)]
#15486

# Initialize the map at the first geometry's centroid
initial_location = list(df_wz_test_filtered['geometry'].iloc[0].centroid.coords)[0][::-1]
m = folium.Map(location=initial_location, zoom_start=15)

# Add the GeoDataFrame to the map
folium.GeoJson(
    df_wz_test_filtered,
    name='geojson'
).add_to(m)

# Add layer control to toggle on/off
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a23d197ea4c101eeda235bfc90e1cb91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a23d197ea4c101eeda235bfc90e1cb91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a23d197ea4c101eeda235bfc90e1cb91 = L.map(
#                 &quot;map_a23d197ea4c101eeda235bfc90e1cb91&quot;,
#                 {
#                     center: [51.03963546531112, -114.12335791064535],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fff2d75a55eae54f0db7e2ba07cb47fb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a23d197ea4c101eeda235bfc90e1cb91);
#
#
#
#         function geo_json_0e5120bb18f362e4b2093fd0e3bde565_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0e5120bb18f362e4b2093fd0e3bde565 = L.geoJson(null, {
#                 onEachFeature: geo_json_0e5120bb18f362e4b2093fd0e3bde565_onEachFeature,
#
#         });
#
#         function geo_json_0e5120bb18f362e4b2093fd0e3bde565_add (data) {
#             geo_json_0e5120bb18f362e4b2093fd0e3bde565
#                 .addData(data)
#                 .addTo(map_a23d197ea4c101eeda235bfc90e1cb91);
#         }
#             geo_json_0e5120bb18f362e4b2093fd0e3bde565_add({&quot;bbox&quot;: [-114.227927656008, 50.8925821139715, -113.9267002078244, 51.17515160683599], &quot;features&quot;: [{&quot;bbox&quot;: [-114.1355023644414, 51.03315900186996, -114.1118110292276, 51.05104930439379], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-114.1227891747781, 51.04905710982406], [-114.1228202811533, 51.04902515658169], [-114.1228383367529, 51.04899275840363], [-114.1228578464733, 51.04896491610903], [-114.1228853399099, 51.04893661610231], [-114.1228482943473, 51.04890105738775], [-114.1227931405434, 51.04887235795464], [-114.122746717149, 51.04885049080502], [-114.1226959283961, 51.04882771110479], [-114.122641531399, 51.04881040952515], [-114.1225929346337, 51.04879675975772], [-114.122544331054, 51.04878082833268], [-114.1224906823383, 51.0487717331149], [-114.122439192833, 51.04876446932153], [-114.1223942290266, 51.0487494504449], [-114.1223456228625, 51.04872666778843], [-114.1222934050999, 51.04871393085457], [-114.122244104006, 51.04870894805713], [-114.1221969649235, 51.04869666268444], [-114.1221374600635, 51.0486645389775], [-114.1220881108976, 51.04863332122899], [-114.1220460124713, 51.04860689134935], [-114.1219901434639, 51.0485772751684], [-114.1219371611158, 51.04854994018474], [-114.1218885553829, 51.04852715664605], [-114.1218421166762, 51.04850438188411], [-114.1217949646507, 51.04848662356034], [-114.1217383782802, 51.04846111593317], [-114.1216883034428, 51.04843286069327], [-114.1216375260631, 51.04840871409004], [-114.1215823867246, 51.04838503047319], [-114.121540305892, 51.04836544117924], [-114.1214858701256, 51.04833263297144], [-114.1214510317141, 51.04830619481211], [-114.1213965964558, 51.048273844687444], [-114.1213494406368, 51.04824923555343], [-114.121295018242, 51.04822144312869], [-114.1212391359102, 51.04818636157207], [-114.1211832854993, 51.0481635857717], [-114.1211274170577, 51.04813944474253], [-114.1210730095682, 51.04811758468142], [-114.1210207620781, 51.04808704837823], [-114.1209736004573, 51.04806563854806], [-114.120928633049, 51.04804879420895], [-114.1208771327064, 51.0480314893279], [-114.1208278141249, 51.04801418113217], [-114.1207734081168, 51.04799277991889], [-114.1207277104695, 51.04798003433776], [-114.1206820159735, 51.04796364048817], [-114.1206363191485, 51.04794633762761], [-114.1205906152899, 51.04793085119281], [-114.1205412981357, 51.04791401050105], [-114.1204977580359, 51.04789168031964], [-114.1204484264629, 51.04786935678138], [-114.1203947448615, 51.04784658821484], [-114.1203425211508, 51.04783064975465], [-114.1202859443007, 51.04780788342799], [-114.1202329972438, 51.04779377073692], [-114.1201815163545, 51.0477837735975], [-114.1201430863749, 51.0477742118183], [-114.1201024727127, 51.0477642027822], [-114.1200524353754, 51.04775009617509], [-114.1199806242581, 51.04772869847525], [-114.1199196973621, 51.04770866515048], [-114.1198696538831, 51.0476918157645], [-114.1198152455055, 51.04766949699192], [-114.1197637439307, 51.04765128383446], [-114.119712978359, 51.04763078514608], [-114.1196466235801, 51.04761531914518], [-114.1195897027135, 51.0476030347857], [-114.1195345699945, 51.04758710757772], [-114.1194845220941, 51.0475684343393], [-114.1194301160457, 51.04754657333753], [-114.1193873189369, 51.04753063397301], [-114.1193380139965, 51.04751789101412], [-114.1192814387138, 51.04750104977219], [-114.1192332042031, 51.04748625240381], [-114.1191726507615, 51.04746690135031], [

# %% [markdown]
# conclusion: using dissolve() can achieve the same result, the syntax is arguably cleaner.

# %% [markdown]
# ### Continue with original testing

# %%
df_wz.school_id.nunique()
# Out:
# 237

# %%
df_wz[df_wz['polygon_number']>3]['school_id'].value_counts()
# Out:
# school_id
# 15486    108
# 174       65
# 226       17
# Name: count, dtype: int64

# %%
def transform_to_geometry(df):
    """
    Transform a DataFrame with individual coordinate points into a DataFrame with polygon geometries.
    
    This function takes a DataFrame that includes school IDs, names, polygon numbers, and pairs
    of latitude and longitude coordinates. It groups the points by school and polygon number to
    create polygons, and then creates a MultiPolygon for schools with multiple polygons.
    The resulting DataFrame has one row per school with a geometry column containing the 
    corresponding MultiPolygon or Polygon.
    
    Parameters:
    - df_wz (pd.DataFrame): A DataFrame with the following columns:
        - 'school_id': An identifier for the school.
        - 'name': The name of the school.
        - 'polygon_number': An identifier for a polygon (in case a school has multiple polygons).
        - 'long_coordinate': Longitude part of the coordinate.
        - 'lat_coordinate': Latitude part of the coordinate.
        
    Returns:
    - pd.DataFrame: A DataFrame with the following columns:
        - 'school_id': An identifier for the school.
        - 'name': The name of the school.
        - 'geometry': A shapely.geometry.Polygon or shapely.geometry.MultiPolygon object representing the school's geometry.
    """
    # Group by 'school_id' and 'polygon_number' to create distinct polygons
    grouped = df.groupby(['school_id', 'polygon_number'])
    
    # List to hold the DataFrame rows
    rows_list = []
    
    # Iterate over the groups and create polygons
    for (school_id, polygon_number), group in grouped:
        # Sort the group by lat/long if necessary to ensure the points are in the correct order
        #group = group.sort_values(['lat_coordinate', 'long_coordinate'])
        
        # Create a polygon using the coordinates from the group
        polygon = Polygon(zip(group['long_coordinate'], group['lat_coordinate']))
        
        # Add the polygon data to our list
        rows_list.append({
            'school_id': school_id,
            'name': group['name'].iloc[0],  # Assumes all names are the same for the same school_id
            'geometry': polygon
        })
    
    # Convert the list of rows into a DataFrame
    schools_geometry = pd.DataFrame(rows_list)
    
    # Group by 'school_id' and 'name' and create MULTIPOLYGON where necessary
    schools_geometry = schools_geometry.groupby(['school_id', 'name'])['geometry'].apply(
        lambda x: MultiPolygon(x.tolist()) if len(x) > 1 else x.iloc[0]
    ).reset_index()
    
    return schools_geometry

# %%
df_wz_t = transform_to_geometry(df_wz)

# %%
df_wz_test[df_wz_test['geometry']!= df_wz_t['geometry']]['school_id'].to_list()
# Out:
# [7, 31, 129, 146, 167, 173, 174, 182, 184, 201, 226, 15486]

# %%
df_wz_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   school_id  237 non-null    int64
#  1   name       237 non-null    object
#  2   geometry   237 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 5.7+ KB

# %%
gdf_wz_t = gpd.GeoDataFrame(
    df_wz_t, geometry='geometry', crs="EPSG:4326"
)

# %%
gdf_wz_t.head(3)
# Out:
#    school_id                       name  \
# 0          6            Richmond School
# 1          7  Alexander Ferguson School
# 2          8      Jennie Elliott School
#
#                                             geometry
# 0  POLYGON ((-114.11125 51.03784, -114.11326 51.0...
# 1  MULTIPOLYGON (((-114.12274 51.04907, -114.1227...
# 2  POLYGON ((-114.13453 51.00579, -114.13608 51.0...

# %% [markdown]
# Check the results:

# %%
id_interest = [7, 31, 129, 146, 167, 173, 174, 182, 184, 201, 226, 15486]
gdf_wz_filtered = gdf_wz_t[gdf_wz_t['school_id'].isin(id_interest)]
#15486


# Initialize the map at the first geometry's centroid
initial_location = list(gdf_wz_filtered['geometry'].iloc[0].centroid.coords)[0][::-1]
m = folium.Map(location=initial_location, zoom_start=15)

# Add the GeoDataFrame to the map
folium.GeoJson(
    gdf_wz_filtered,
    name='geojson'
).add_to(m)

# Add layer control to toggle on/off
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b36bff9f87261f2f72a06f99e3ad97ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b36bff9f87261f2f72a06f99e3ad97ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b36bff9f87261f2f72a06f99e3ad97ff = L.map(
#                 &quot;map_b36bff9f87261f2f72a06f99e3ad97ff&quot;,
#                 {
#                     center: [51.039635465311164, -114.12335791064541],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f037e1bcc914636b457049dc74e3e6a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b36bff9f87261f2f72a06f99e3ad97ff);
#
#
#
#         function geo_json_6588cd48e385b183e719a7f8e1d3ed4c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json
-114.1229231222402, 51.05005788309288], [-114.1229413054188, 51.05008980352582], [-114.1229609307396, 51.05011716519746], [-114.1229834859162, 51.05015273151567], [-114.1230045563316, 51.05018191673229], [-114.1230270881283, 51.05020790942228], [-114.1230499879353, 51.05024142036514], [-114.1230707098661, 51.05027631021797], [-114.1230903358305, 51.05030457982497], [-114.1231186755006, 51.05033740664726], [-114.1231462879374, 51.05037068406198], [-114.1231630360427, 51.05040444071754], [-114.1231696187735, 51.05043499826913], [-114.1231754812948, 51.05046784012294], [-114.1231871357905, 51.0504956594696], [-114.1231980603412, 51.05052302111341], [-114.1232097225332, 51.05054856606133], [-114.1232300804017, 51.0505

# %% [markdown]
# ## attendance areas:

# %%
with sqlite3.connect('../database.db') as conn:
    df_aa = pd.read_sql_query('''
                                   SELECT s.school_id, s.name, aa.polygon_number, aa.lat_coordinate, aa.long_coordinate
FROM attendance_areas aa
INNER JOIN schools s on s.school_id = aa.school_id
                                   ''', conn)

# %%
df_aa.head(3)
# Out:
#    school_id                name  polygon_number  lat_coordinate  \
# 0        142  A. E. Cross School               0       51.071998
# 1        142  A. E. Cross School               0       51.071197
# 2        142  A. E. Cross School               0       51.068347
#
#    long_coordinate
# 0      -114.175908
# 1      -114.175905
# 2      -114.175880

# %%
df_aa[df_aa['polygon_number']>2]['school_id'].value_counts()
# Out:
# school_id
# 172    174
# 159     79
# Name: count, dtype: int64

# %%
df_aa[df_aa['school_id']==172].groupby(by=['polygon_number']).first()
# Out:
#                 school_id                      name  lat_coordinate  \
# polygon_number
# 0                     172  James Fowler High School       51.106265
# 1                     172  James Fowler High School       51.110637
# 2                     172  James Fowler High School       51.145173
# 3                     172  James Fowler High School       51.176069
# 4                     172  James Fowler High School       51.197966
#
#                 long_coordinate
# polygon_number
# 0                   -114.082533
# 1                   -113.920327
# 2                   -114.065477
# 3                   -113.918397
# 4                   -114.048094

# %%
df_aa_t = transform_to_geometry(df_aa)

# %%
gdf_aa_t = gpd.GeoDataFrame(
    df_aa_t, geometry='geometry', crs="EPSG:4326"
)

# %%
gdf_aa_t.head(3)
# Out:
#    school_id                       name  \
# 0          6            Richmond School
# 1          7  Alexander Ferguson School
# 2          8      Jennie Elliott School
#
#                                             geometry
# 0  POLYGON ((-114.11123 51.03783, -114.11324 51.0...
# 1  POLYGON ((-114.12244 51.04949, -114.12247 51.0...
# 2  POLYGON ((-114.11798 51.00871, -114.12142 51.0...

# %%
gdf_aa_t[gdf_aa_t['school_id']==172]
# Out:
#      school_id                      name  \
# 157        172  James Fowler High School
#
#                                               geometry
# 157  MULTIPOLYGON (((-114.08253 51.10626, -114.0826...

# %%
gdf_aa_filtered = gdf_aa_t[gdf_aa_t['school_id'] == 172]

# Initialize the map at the first geometry's centroid
initial_location = list(gdf_aa_filtered['geometry'].iloc[0].centroid.coords)[0][::-1]
m_aa = folium.Map(location=initial_location, zoom_start=15)

# Add the GeoDataFrame to the map
folium.GeoJson(
    gdf_aa_filtered,
    name='geojson'
).add_to(m_aa)

# Add layer control to toggle on/off
folium.LayerControl().add_to(m_aa)

# Display the map
m_aa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_
-114.0947340569094, 51.08471044204033], [-114.0947435932934, 51.08304502328944], [-114.0930061117858, 51.08304641839036], [-114.0927608729652, 51.08303769186924], [-114.0925843693807, 51.08300571166338], [-114.0924257523641, 51.08294516763791], [-114.0922820355973, 51.08285782689551], [-114.092193462511, 51.08280812363241], [-114.0920992358584, 51.08274667255133], [-114.0917232104609, 51.08251362941476], [-114.0913387346983, 51.08226861471561], [-114.0895724155157, 51.08114302178259], [-114.0888254659918, 51.08066703978309], [-114.0884707848266, 51.08044101870076], [-114.088107831081, 51.08020975099815], [-114.0867695555177, 51.07935699111612], [-114.0859538415372, 51.07883737247457], [-114.0856620182882, 51.07865166294821], [-114.0853530709159, 51.07839545820858], [-114.085062832637, 51.07808910806092], [-114.0850297489409, 51.07801618623946], [-114.0848106996221, 51.07770617698689], [-114.0846247959125, 51.07720866973815], [-114.0846122004302, 51.07664908173258], [-114.084608140791, 51.07591134876123], [-114.0845917511224, 51.07478410261244], [-114.0831433563441, 51.07478139179299], [-114.0828735947208, 51.07488134730249], [-114.0826628511511, 51.07500946471932], [-114.0824118637056, 51.07510466651891], [-114.0822873334505, 51.0751300943714], [-114.082040629226, 51.07515553327784], [-114.0817202425417, 51.07514953707422]

# %% [markdown]
# ## rental listings:

# %%
with sqlite3.connect('../database.db') as conn:
    df_listings = pd.read_sql_query('''
                                   SELECT *
                                   FROM rental_listings
                                   
                                   ''', conn)

# %%
gdf_listings = gpd.GeoDataFrame(df_listings,geometry=gpd.points_from_xy(df_listings['longitude'], df_listings['latitude']), crs="EPSG:4326"
)

# %%
gdf_listings.head(3)
# Out:
#      id     city    community   latitude   longitude  \
# 0  1500  Calgary     Woodbine  50.942310 -114.125200
# 1  2248  Calgary  Falconridge  51.108143 -113.936489
# 2  3078  Calgary   Eau Claire  51.050855 -114.077663
#
#                                                 link        type  price  beds  \
# 0  /ab/calgary/rentals/main-floor/3-bedrooms/wood...  Main Floor   2100   3.0
# 1  /ab/calgary/rentals/apartment/1-bedroom/falcon...   Apartment   1450   1.0
# 2  /ab/calgary/rentals/condo/1-bedroom/eau-claire...  Condo Unit   1900   1.0
#
#    has_den  sq_feet  baths  cats  dogs      activation_date  \
# 0        0   1200.0    1.0     0     0  2024-01-03 13:38:58
# 1        0    500.0    1.0     1     1  2024-01-05 07:49:33
# 2        0    600.0    1.0     0     0  2023-12-30 15:00:58
#
#            last_update  is_active                     geometry
# 0  2024-01-06 23:13:21          1  POINT (-114.12520 50.94231)
# 1  2024-01-06 23:13:21          1  POINT (-113.93649 51.10814)
# 2  2024-01-06 23:13:21          1  POINT (-114.07766 51.05085)

# %% [markdown]
# # 2. Spatial Joins

# %% [markdown]
# ## 2.1 Walk zones and rental listings:

# %%
gdf_wz_listings = gpd.sjoin(gdf_listings,gdf_wz_t, how="inner",lsuffix='l',rsuffix='r')

# %%
gdf_wz_listings.head(3)
# Out:
#         id     city    community   latitude   longitude  \
# 1     2248  Calgary  Falconridge  51.108143 -113.936489
# 100  33988  Calgary  Castleridge  51.103780 -113.956850
# 146  58367  Calgary  Castleridge  51.103780 -113.956850
#
#                                                   link        type  price  \
# 1    /ab/calgary/rentals/apartment/1-bedroom/falcon...   Apartment   1450
# 100  /ab/calgary/rentals/main-floor/3-bedrooms/cast...  Main Floor   1950
# 146  /ab/calgary/rentals/house/3-bedrooms/castlerid...       House   2375
#
#      beds  has_den  ...  baths  cats  dogs      activation_date  \
# 1     1.0        0  ...    1.0     1     1  2024-01-05 07:49:33
# 100   3.0        0  ...    1.5     0     0  2024-01-03 07:48:14
# 146   3.0        0  ...    2.0     0     0  2023-12-30 15:00:58
#
#              last_update is_active                     geometry index_r  \
# 1    2024-01-06 23:13:21         1  POINT (-113.93649 51.10814)     149
# 100  2024-01-06 23:13:21         1  POINT (-113.95685 51.10378)     149
# 146  2024-01-06 23:13:21         1  POINT (-113.95685 51.10378)     149
#
#      school_id              name
# 1          164  Terry Fox School
# 100        164  Terry Fox School
# 146        164  Terry Fox School
#
# [3 rows x 21 columns]

# %%
gdf_wz_listings.columns
# Out:
# Index(['id', 'city', 'community', 'latitude', 'longitude', 'link', 'type',
#        'price', 'beds', 'has_den', 'sq_feet', 'baths', 'cats', 'dogs',
#        'activation_date', 'last_update', 'is_active', 'geometry', 'index_r',
#        'school_id', 'name'],
#       dtype='object')

# %%
school_id_plot = 226
gdf_wz_filtered = gdf_wz_t[gdf_wz_t['school_id'] == school_id_plot]

# Initialize the map at the first geometry's centroid
initial_location = list(gdf_wz_filtered['geometry'].iloc[0].centroid.coords)[0][::-1]
m = folium.Map(location=initial_location, zoom_start=15)

# Add the GeoDataFrame to the map
folium.GeoJson(
    gdf_wz_filtered,
    name='geojson'
).add_to(m)

# Add layer control to toggle on/off
folium.LayerControl().add_to(m)

# Filter the merged listings for the specific school_id
listings_for_school = gdf_wz_listings[gdf_wz_listings['school_id'] == school_id_plot]

# Initialize the map at the first geometry's centroid
initial_location = list(gdf_wz_filtered['geometry'].iloc[0].centroid.coords)[0][::-1]
m = folium.Map(location=initial_location, zoom_start=15)

# Add the GeoDataFrame to the map (school's walk zone)
folium.GeoJson(
    gdf_wz_filtered,
    name='School Walk Zone'
).add_to(m)

# Add each rental listing as a point on the map
for index, row in listings_for_school.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=folium.Popup(f"{row['city']}, {row['type']}, Price: {row['price']}", max_width=300),
        icon=folium.Icon(color="blue", icon="home")
    ).add_to(m)

# Add layer control to toggle on/off
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_232c26c79b39a8ce21291006cd2d5413 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_232c26c79b39a8ce21291006cd2d5413&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_232c26c79b39a8ce21291006cd2d5413 = L.map(
#                 &quot;map_232c26c79b39a8ce21291006cd2d5413&quot;,
#                 {
#                     center: [51.131181501019164, -114.1920288427034],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae9b6cc2d1831bab815cbc0bf02e271e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_232c26c79b39a8ce21291006cd2d5413);
#
#
#
#         function geo_json_baf5bb8acb31394728b2241ac60c58eb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json
094], [-114.1901612875301, 51.14969831095801], [-114.1902177967246, 51.14969391576555], [-114.19014389507, 51.14932386293077], [-114.1901299516686, 51.14925680167741], [-114.1902922257928, 51.14924345442525], [-114.1905016043629, 51.14922437663245], [-114.1904854390252, 51.14915767598748], [-114.1904870943807, 51.14908621330528], [-114.1904874713163, 51.14908014092259], [-114.1904926502732, 51.14899670847104], [-114.1905101403012, 51.14892831511141], [-114.1905276572946, 51.14886613620291], [-114.1905549963772, 51.14879151049578], [-114.1905918112226, 51.1487195287977], [-114.1906025269617, 51.14869857695845], [-114.1

# %% [markdown]
# ## 2.2 Attendance area and rental listings

# %%
gdf_aa_listings = gpd.sjoin(gdf_listings,gdf_aa_t, how="inner",lsuffix='l',rsuffix='r')

# %%
school_id_plot = 172
gdf_aa_filtered = gdf_aa_t[gdf_aa_t['school_id'] == school_id_plot]

# Initialize the map at the first geometry's centroid
#initial_location = list(gdf_aa_filtered['geometry'].iloc[0].centroid.coords)[0][::-1]
#m_aa = folium.Map(location=initial_location, zoom_start=15)

# Add the GeoDataFrame to the map
'''folium.GeoJson(
    gdf_aa_filtered,
    name='geojson'
).add_to(m_aa)'''

# Add layer control to toggle on/off
#folium.LayerControl().add_to(m_aa)

# Filter the merged listings for the specific school_id
listings_for_school = gdf_aa_listings[gdf_aa_listings['school_id'] == school_id_plot]

# Initialize the map at the first geometry's centroid
initial_location = list(gdf_aa_filtered['geometry'].iloc[0].centroid.coords)[0][::-1]
m_aa = folium.Map(location=initial_location, zoom_start=15)

# Add the GeoDataFrame to the map (school's walk zone)
folium.GeoJson(
    gdf_aa_filtered,
    name='School Attendance Area'
).add_to(m_aa)

# Add each rental listing as a point on the map
for index, row in listings_for_school.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=folium.Popup(f"{row['city']}, {row['type']}, Price: {row['price']}", max_width=300),
        icon=folium.Icon(color="blue", icon="home")
    ).add_to(m_aa)

# Add layer control to toggle on/off
folium.LayerControl().add_to(m_aa)

# %%
# Display the map
m_aa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d76035fa2052f27b591af0bae25cc344 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d76035fa2052f27b591af0bae25cc344&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d76035fa2052f27b591af0bae25cc344 = L.map(
#                 &quot;map_d76035fa2052f27b591af0bae25cc344&quot;,
#                 {
#                     center: [51.14107206851471, -114.00900486541056],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5924f6344e0736cba4e5c2771ce1fb53 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d76035fa2052f27b591af0bae25cc344);
#
#
#
#         function geo_json_6af713c6a21f14757457f188b0c42555_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6af713c6a21f14757457f188b0c42555 = L.geoJson(null, {
#                 onEachFeature: geo_json_6af713c6a21f14757457f188b0c42555_onEachFeature,
#
#         });
#
#         function geo_json_6af713c6a21f14757457f188b0c42555_add (data) {
#             geo_json_6af713c6a21f14757457f188b0c42555
#                 .addData(data)
#                 .addTo(map_d76035fa2052f27b591af0bae25cc344);
#         }
#             geo_json_6af713c6a21f14757457f188b0c42555_add({&quot;bbox&quot;: [-114.0947454678074, 51.07478139179299, -113.9143879804598, 51.19798655897684], &quot;features&quot;: [{&quot;bbox&quot;: [-114.0947454678074, 51.07478139179299, -113.9143879804598, 51.19798655897684], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[