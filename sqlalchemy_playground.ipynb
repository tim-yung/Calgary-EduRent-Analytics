# %% [markdown]
# #### Creating tables and engine

# %%
from typing import List
from typing import Optional
from sqlalchemy import ForeignKey
from sqlalchemy import String
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy.orm import Mapped
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import relationship

class Base(DeclarativeBase):
    pass

class School(Base):
    __tablename__ = "school"
    school_id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[str] 
    attendance_area_list: Mapped[List["Attendance_Area"]] = relationship(back_populates="school")
    def __repr__(self) -> str:
        return f"School(id={self.id!r}, name={self.name!r}, attendance area={self.attendance_area_list!r})"

class Attendance_Area(Base):
    __tablename__ = "attendance_area"
    id: Mapped[int] = mapped_column(primary_key=True)
    polygon_number: Mapped[int]
    lat_coordinate:Mapped[float]
    long_coordinate: Mapped[float]
    school_id = mapped_column(ForeignKey("school.school_id"))
    school: Mapped[School] = relationship(back_populates="attendance_area_list")
    def __repr__(self) -> str:
        return f"Attendance_Area(id={self.id!r}, polygon_number={self.polygon_number!r}, lat_coordinate={self.lat_coordinate!r}, long_coordinate={self.long_coordinate!r})"

# %%
from sqlalchemy import create_engine
engine = create_engine("sqlite:///test_orm.db", echo=True)

# %%
Base.metadata.create_all(engine)
# Out:
# 2023-11-20 07:41:01,642 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-20 07:41:01,642 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school")
# 2023-11-20 07:41:01,642 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-11-20 07:41:01,642 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school")
# 2023-11-20 07:41:01,650 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-11-20 07:41:01,652 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("attendance_area")
# 2023-11-20 07:41:01,652 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-11-20 07:41:01,654 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("attendance_area")
# 2023-11-20 07:41:01,654 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-11-20 07:41:01,657 INFO sqlalchemy.engine.Engine
# CREATE TABLE school (
# 	school_id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	PRIMARY KEY (school_id)
# )
#
#
# 2023-11-20 07:41:01,658 INFO sqlalchemy.engine.Engine [no key 0.00081s] ()
# 2023-11-20 07:41:01,668 INFO sqlalchemy.engine.Engine
# CREATE TABLE attendance_area (
# 	id INTEGER NOT NULL,
# 	polygon_number INTEGER NOT NULL,
# 	lat_coordinate FLOAT NOT NULL,
# 	long_coordinate FLOAT NOT NULL,
# 	school_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(school_id) REFERENCES school (school_id)
# )
#
#
# 2023-11-20 07:41:01,668 INFO sqlalchemy.engine.Engine [no key 0.00119s] ()
# 2023-11-20 07:41:01,668 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# #### adding data individually

# %%
mkp = School(name='Ma Ko Pan Memorial College')
cuhk = School(name='CUHK')

# %%
a1 = Attendance_Area(polygon_number=1, lat_coordinate = 100, long_coordinate = -50, school = mkp)
a2 = Attendance_Area(polygon_number=1, lat_coordinate = 90, long_coordinate = -40, school = mkp)
a3 = Attendance_Area(polygon_number=2, lat_coordinate = 80, long_coordinate = -30, school = mkp)
a4 = Attendance_Area(polygon_number=2, lat_coordinate = 70, long_coordinate = -20, school = mkp)

b1 = Attendance_Area(polygon_number=1, lat_coordinate = 100, long_coordinate = -50, school = cuhk)
b2 = Attendance_Area(polygon_number=1, lat_coordinate = 90, long_coordinate = -40, school = cuhk)
b3 = Attendance_Area(polygon_number=2, lat_coordinate = 80, long_coordinate = -30, school = cuhk)
b4 = Attendance_Area(polygon_number=2, lat_coordinate = 70, long_coordinate = -20, school = cuhk)

# %%
from sqlalchemy.orm import Session
session = Session(engine)

# %%
session.add_all([mkp,a1,a2,a3,a4,cuhk,b1,b2,b3,b4])

# %%
session.flush()
# Out:
# 2023-11-20 07:41:01,754 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-20 07:41:01,756 INFO sqlalchemy.engine.Engine INSERT INTO school (name) VALUES (?) RETURNING school_id
# 2023-11-20 07:41:01,758 INFO sqlalchemy.engine.Engine [generated in 0.00010s (insertmanyvalues) 1/2 (ordered; batch not supported)] ('Ma Ko Pan Memorial College',)
# 2023-11-20 07:41:01,759 INFO sqlalchemy.engine.Engine INSERT INTO school (name) VALUES (?) RETURNING school_id
# 2023-11-20 07:41:01,760 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] ('CUHK',)
# 2023-11-20 07:41:01,763 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?) RETURNING id
# 2023-11-20 07:41:01,764 INFO sqlalchemy.engine.Engine [generated in 0.00014s (insertmanyvalues) 1/8 (ordered; batch not supported)] (1, 100.0, -50.0, 1)
# 2023-11-20 07:41:01,764 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?) RETURNING id
# 2023-11-20 07:41:01,765 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/8 (ordered; batch not supported)] (1, 90.0, -40.0, 1)
# 2023-11-20 07:41:01,766 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?) RETURNING id
# 2023-11-20 07:41:01,767 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/8 (ordered; batch not supported)] (2, 80.0, -30.0, 1)
# 2023-11-20 07:41:01,768 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?) RETURNING id
# 2023-11-20 07:41:01,768 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/8 (ordered; batch not supported)] (2, 70.0, -20.0, 1)
# 2023-11-20 07:41:01,769 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?) RETURNING id
# 2023-11-20 07:41:01,769 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/8 (ordered; batch not supported)] (1, 100.0, -50.0, 2)
# 2023-11-20 07:41:01,770 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?) RETURNING id
# 2023-11-20 07:41:01,772 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/8 (ordered; batch not supported)] (1, 90.0, -40.0, 2)
# 2023-11-20 07:41:01,772 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?) RETURNING id
# 2023-11-20 07:41:01,772 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/8 (ordered; batch not supported)] (2, 80.0, -30.0, 2)
# 2023-11-20 07:41:01,772 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?) RETURNING id
# 2023-11-20 07:41:01,772 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/8 (ordered; batch not supported)] (2, 70.0, -20.0, 2)

# %%
mkp.attendance_area_list
# Out:
# [Attendance_Area(id=1, polygon_number=1, lat_coordinate=100, long_coordinate=-50),
#  Attendance_Area(id=2, polygon_number=1, lat_coordinate=90, long_coordinate=-40),
#  Attendance_Area(id=3, polygon_number=2, lat_coordinate=80, long_coordinate=-30),
#  Attendance_Area(id=4, polygon_number=2, lat_coordinate=70, long_coordinate=-20)]

# %%
b1.school_id
# Out:
# 2

# %% [markdown]
# #### adding data by bulk

# %%
from sqlalchemy import insert

# Define your data:
schools_data = [
    {'name': 'Ma Ko Pan Memorial College'},
    {'name': 'CUHK'}
]

# %%
# Step 1: Insert school records and fetch their primary keys
stmt = insert(School).values(schools_data)
result = session.execute(stmt)
# Query for the inserted schools to get their primary keys
inserted_schools = session.query(School).filter(School.name.in_(['Ma Ko Pan Memorial College', 'CUHK'])).all()
school_ids = [school.school_id for school in inserted_schools]
print(school_ids)
# Out:
# 2023-11-20 07:41:01,842 INFO sqlalchemy.engine.Engine INSERT INTO school (name) VALUES (?), (?)
# 2023-11-20 07:41:01,843 INFO sqlalchemy.engine.Engine [no key 0.00115s] ('Ma Ko Pan Memorial College', 'CUHK')
# 2023-11-20 07:41:01,846 INFO sqlalchemy.engine.Engine SELECT school.school_id AS school_school_id, school.name AS school_name
# FROM school
# WHERE school.name IN (?, ?)
# 2023-11-20 07:41:01,847 INFO sqlalchemy.engine.Engine [generated in 0.00151s] ('Ma Ko Pan Memorial College', 'CUHK')
# [1, 2, 3, 4]

# %%
# Step 2: Insert Attendance_Area records
attendance_areas_data = [
    {'polygon_number': 1, 'lat_coordinate': 100, 'long_coordinate': -50, 'school_id': school_ids[0]},
    {'polygon_number': 1, 'lat_coordinate': 90, 'long_coordinate': -40, 'school_id': school_ids[0]},
    {'polygon_number': 2, 'lat_coordinate': 80, 'long_coordinate': -30, 'school_id': school_ids[0]},
    {'polygon_number': 2, 'lat_coordinate': 70, 'long_coordinate': -20, 'school_id': school_ids[0]},
    {'polygon_number': 1, 'lat_coordinate': 100, 'long_coordinate': -50, 'school_id': school_ids[1]},
    {'polygon_number': 1, 'lat_coordinate': 90, 'long_coordinate': -40, 'school_id': school_ids[1]},
    {'polygon_number': 2, 'lat_coordinate': 80, 'long_coordinate': -30, 'school_id': school_ids[1]},
    {'polygon_number': 2, 'lat_coordinate': 70, 'long_coordinate': -20, 'school_id': school_ids[1]},
]
stmt = insert(Attendance_Area).values(attendance_areas_data)
result = session.execute(stmt)
# Out:
# 2023-11-20 07:41:01,876 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?)
# 2023-11-20 07:41:01,878 INFO sqlalchemy.engine.Engine [no key 0.00200s] (1, 100.0, -50.0, 1, 1, 90.0, -40.0, 1, 2, 80.0, -30.0, 1, 2, 70.0, -20.0, 1, 1, 100.0, -50.0, 2, 1, 90.0, -40.0, 2, 2, 80.0, -30.0, 2, 2, 70.0, -20.0, 2)

# %%
from sqlalchemy import select
result = session.execute(select(School))
# Out:
# 2023-11-20 07:41:01,907 INFO sqlalchemy.engine.Engine SELECT school.school_id, school.name
# FROM school
# 2023-11-20 07:41:01,908 INFO sqlalchemy.engine.Engine [generated in 0.00143s] ()

# %%
'''for row in result:
    print(row)'''
session.rollback()
# Out:
# 2023-11-20 07:41:01,932 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### Test data insert by loading data from csv

# %%
import pandas as pd
school_list = pd.read_csv('school_list.csv')

# %%
school_list.head(2)
# Out:
#    school_id                name                                 address  \
# 0        142  A. E. Cross School       3445 37 St SW Calgary, AB T3E 3C2
# 1        108    Abbeydale School  320 Abergale Dr NE Calgary, AB T2A 6W2
#
#           phone           fax                email  \
# 0  403-777-7410  587-933-9733    AECross@cbe.ab.ca
# 1  403-777-6970  587-933-9702  abbeydale@cbe.ab.ca
#
#                                     website      school_hour grades  ward  \
# 0    http://school.cbe.ab.ca/school/aecross  9:10am - 3:50pm    7-9     6
# 1  http://school.cbe.ab.ca/school/abbeydale      8:00 - 2:40    K-5    10
#
#    ...  grade_5_enrolment  grade_6_enrolment grade_7_enrolment  \
# 0  ...                  0                  0               201
# 1  ...                 49                  0                 0
#
#   grade_8_enrolment  grade_9_enrolment  grade_10_enrolment  \
# 0               208                185                   0
# 1                 0                  0                   0
#
#    grade_11_enrolment  grade_12_enrolment  \
# 0                   0                   0
# 1                   0                   0
#
#                                      attendance_area  \
# 0  ['-114.1759081958474 51.071997543479668 0 0, -...
# 1  ['-113.9351192223485 51.066971217059027 0 0, -...
#
#                                            walk_zone
# 0  ['-114.1179390176414 51.0173921233336 0 0, -11...
# 1  ['-113.9351406030196 51.066972424404149 0, -11...
#
# [2 rows x 29 columns]

# %%
import ast
school_list['attendance_area_conv'] = school_list['attendance_area'].apply(lambda x: ast.literal_eval(x))

# %%
sch_0 = school_list.iloc[0]

# %%
sch_0_data=[{
    'school_id': int(sch_0.school_id),
    'name':sch_0['name']
}]

# %%
sch_0_data
# Out:
# [{'school_id': 142, 'name': 'A. E. Cross School'}]

# %%
def parse_attendance_area(school):
    attendance_areas = []
    for i, polygon in enumerate(school.attendance_area_conv):
        for coordinate in polygon.split(','):
            lat, long = coordinate.split()[:2]
            attendance_areas.append({
                'school_id': school.school_id,
                'polygon_number': i,
                'lat_coordinate': float(lat),
                'long_coordinate': float(long)
            })
    return attendance_areas

# %%
sch_0_attendance_area = parse_attendance_area(sch_0)
print(len(sch_0_attendance_area))
sch_0_attendance_area[:5]
# Out:
# 5618
# [{'school_id': 142,
#   'polygon_number': 0,
#   'lat_coordinate': -114.1759081958474,
#   'long_coordinate': 51.07199754347967},
#  {'school_id': 142,
#   'polygon_number': 0,
#   'lat_coordinate': -114.1759052874672,
#   'long_coordinate': 51.07119685412689},
#  {'school_id': 142,
#   'polygon_number': 0,
#   'lat_coordinate': -114.1758802599086,
#   'long_coordinate': 51.06834739140711},
#  {'school_id': 142,
#   'polygon_number': 0,
#   'lat_coordinate': -114.175875022906,
#   'long_coordinate': 51.06779152532258},
#  {'school_id': 142,
#   'polygon_number': 0,
#   'lat_coordinate': -114.1762832040941,
#   'long_coordinate': 51.06796095349047}]

# %% [markdown]
# Problem to be solved: the polygon number is lost in parsing, now there is only polygon_number 0 for all.

# %%
stmt1 = insert(School).values(sch_0_data)
stmt2=insert(Attendance_Area).values(sch_0_attendance_area)

# %%
session.execute(stmt1)
# Out:
# 2023-11-20 07:41:02,901 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-20 07:41:02,902 INFO sqlalchemy.engine.Engine INSERT INTO school (school_id, name) VALUES (?, ?)
# 2023-11-20 07:41:02,903 INFO sqlalchemy.engine.Engine [no key 0.00078s] (142, 'A. E. Cross School')

# %%
session.execute(stmt2)
# Out:
# 2023-11-20 07:41:03,383 INFO sqlalchemy.engine.Engine INSERT INTO attendance_area (polygon_number, lat_coordinate, long_coordinate, school_id) VALUES (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?), (?, ?, ?, ?),  ...
# 2023-11-20 07:41:03,383 INFO sqlalchemy.engine.Engine [no key 0.07583s] (0, -114.1759081958474, 51.07199754347967, 142, 0, -114.1759052874672, 51.07119685412689, 142, 0, -114.1758802599086, 51.06834739140711, 142, 0, -114.175875022906, 51.06779152532258, 142, 0, -114.1762832040941, 51.06796095349047, 142, 0, -114.1771896237207, 51.0683620621231, 142, 0, -114.1785454427384, 51.06901705044878, 142, 0, -114.1799049078428, 51.06974988619821, 142, 0, -114.1810879743634, 51.07044994589256, 142, 0, -114.1822657909812, 51.07122253244508, 142, 0, -114.1831772163564, 51.07187418807959, 142, 0, -114.1842351914022, 51.07268060968222, 142, 0, -114.1850334429666 ... 22372 parameters truncated ... 51.0716449628854, 142, 0, -114.1755446172873, 51.07167552608811, 142, 0, -114.1755729609556, 51.07170792735103, 142, 0, -114.1756107356456, 51.07174351387413, 142, 0, -114.1756506905158, 51.07177453124071, 142, 0, -114.1756732257082, 51.07179871563051, 142, 0, -114.1756979328142, 51.07182746262033, 142, 0, -114.1757349893564, 51.07186213413173, 142, 0, -114.1757698538485, 51.07189406616968, 142, 0, -114.1758112678584, 51.07192599823603, 142, 0, -114.1758635530483, 51.07196158083254, 142, 0, -114.1759071338907, 51.07199670094831, 142, 0, -114.1759081958474, 51.07199754347967, 142)

# %%
result = session.execute(select(Attendance_Area))
# Out:
# 2023-11-20 07:41:03,439 INFO sqlalchemy.engine.Engine SELECT attendance_area.id, attendance_area.polygon_number, attendance_area.lat_coordinate, attendance_area.long_coordinate, attendance_area.school_id
# FROM attendance_area
# 2023-11-20 07:41:03,439 INFO sqlalchemy.engine.Engine [generated in 0.00160s] ()

# %%
for rows in result:
    print(rows)
# Out:
# (Attendance_Area(id=1, polygon_number=0, lat_coordinate=-114.1759081958474, long_coordinate=51.07199754347967),)
# (Attendance_Area(id=2, polygon_number=0, lat_coordinate=-114.1759052874672, long_coordinate=51.07119685412689),)
# (Attendance_Area(id=3, polygon_number=0, lat_coordinate=-114.1758802599086, long_coordinate=51.06834739140711),)
# (Attendance_Area(id=4, polygon_number=0, lat_coordinate=-114.175875022906, long_coordinate=51.06779152532258),)
# (Attendance_Area(id=5, polygon_number=0, lat_coordinate=-114.1762832040941, long_coordinate=51.06796095349047),)
# (Attendance_Area(id=6, polygon_number=0, lat_coordinate=-114.1771896237207, long_coordinate=51.0683620621231),)
# (Attendance_Area(id=7, polygon_number=0, lat_coordinate=-114.1785454427384, long_coordinate=51.06901705044878),)
# (Attendance_Area(id=8, polygon_number=0, lat_coordinate=-114.1799049078428, long_coordinate=51.06974988619821),)
# (Attendance_Area(id=9, polygon_number=0, lat_coordinate=-114.1810879743634, long_coordinate=51.07044994589256),)
# (Attendance_Area(id=10, polygon_number=0, lat_coordinate=-114.1822657909812, long_coordinate=51.07122253244508),)
# (Attendance_Area(id=11, polygon_number=0, lat_coordinate=-114.1831772163564, long_coordinate=51.07187418807959),)
# (Attendance_Area(id=12, polygon_number=0, lat_coordinate=-114.1842351914022, long_coordinate=51.07268060968222),)
# (Attendance_Area(id=13, polygon_number=0, lat_coordinate=-114.1850334429666, long_coordinate=51.07336855591509),)
# (Attendance_Area(id=14, polygon_number=0, lat_coordinate=-114.1859493932998, long_coordinate=51.07427164868849),)
# (Attendance_Area(id=15, polygon_number=0, lat_coordinate=-114.1868618032626, long_coordinate=51.07526508446969),)
# (Attendance_Area(id=16, polygon_number=0, lat_coordinate=-114.1876533401927, long_coordinate=51.07496731215159),)
# (Attendance_Area(id=17, polygon_number=0, lat_coordinate=-114.1876546926102, long_coordinate=51.07427993707888),)
# (Attendance_Area(id=18, polygon_number=0, lat_coordinate=-114.1877981314847, long_coordinate=51.07428971497475),)
# (Attendance_Area(id=19, polygon_number=0, lat_coordinate=-114.1935377974368, long_coordinate=51.07428962756344),)
# (Attendance_Area(id=20, polygon_number=0, lat_coordinate=-114.1964060233379, long_coordinate=51.07428947818567),)
# (Attendance_Area(id=21, polygon_number=0, lat_coordinate=-114.1993091499088, long_coordinate=51.07428925557537),)
# (Attendance_Area(id=22, polygon_number=0, lat_coordinate=-114.1993398582938, long_coordinate=51.07430119637425),)
# (Attendance_Area(id=23, polygon_number=0, lat_coordinate=-114.1994064562218, long_coordinate=51.07432801233773),)
# (Attendance_Area(id=24, polygon_number=0, lat_coordinate=-114.1994501669768, long_coordinate=51.0743455333088),)
# (Attendance_Area(id=25, polygon_number=0, lat_coordinate=-114.1995020972276, long_coordinate=51.07436506561607),)
# (Attendance_Area(id=26, polygon_number=0, lat_coordinate=-114.1995295782086, long_coordinate=51.07437309775788),)
# (Attendance_Area(id=27, polygon_number=0, lat_coordinate=-114.1995521619784, long_coordinate=51.07437652204246),)
# (Attendance_Area(id=28, polygon_number=0, lat_coordinate=-114.1995735259205, long_coordinate=51.07438033226519),)
# (Attendance_Area(id=29, polygon_number=0, lat_coordinate=-114.1999290873529, long_coordinate=51.07438177348357),)
# (Attendance_Area(id=30, polygon_number=0, lat_coordinate=-114.2020693720521, long_coordinate=51.07438037430226),)
# (Attendance_Area(id=31, polygon_number=0, lat_coordinate=-114.2038653837349, long_coordinate=51.07556870486865),)
# (Attendance_Area(id=32, polygon_number=0, lat_coordinate=-114.2063768258685, long_coordinate=51.07673011996735),)
# (Attendance_Area(id=33, polygon_number=0, lat_coordinate=-114.2107222267683, long_coordinate=51.07904115657138),)
# (Attendance_Area(id=34, polygon_number=0, lat_coordinate=-114.2108731486249, long_coordinate=51.07898992277664),)
# (Attendance_Area(id=35, polygon_number=0, lat_coordinate=-114.2109513580519, long_coordinate=51.07650413647794),)
# (Attendance_Area(id=36, polygon_number=0, lat_coordinate=-114.2109622574033, long_coordinate=51.07554342200903),)
# (Attendance_Area(id=37, polygon_number=0, lat_coordinate=-114.2109624269672, long_coordinate=51.07540559524521),)
# (Attendance_Area(id=38, polygon_number=0, lat_coordinate=-114.2111056450645, long_coordinate=51.07542301765248),)
# (Attendance_Area(id=39, polygon_number=0, lat_coordinate=-114.2168417087643, long_coordinate=51.07612065813636),)
# (Attendance_Area(id=40, polygon_number=0, lat_coordinate=-114.2203302242212, long_coordinate=51.07611358801806),)
# (Attendance_Area(id=41, polygon_number=0, lat_coordinate=-114.2207312008739, long_coordinate=51.07611268329228),)
# (Attendance_Area(id=42, polygon_number=0, lat_coordinate=-114.2209451898802, long_coordinate=51.07611213882483),)
# (Attendance_Area(id=43, polygon_number=0, lat_coordinate=-114.2217071936575, long_coordinate=51.07611067193623),)
# (Attendance_Area(id=44, polygon_number=0, lat_coordinate=-114.2225648569418, long_coordinate=51.0761089227141),)
# (Attendance_Area(id=45, polygon_number=0, lat_coordinate=-114.2225804527624, long_coordinate=51.07610888493129),)
# (Attendance_Area(id=46, polygon_number=0, lat_coordinate=-114.2225820500008, long_coordinate=51.07431713667147),)
# (Attendance_Area(id=47, polygon_number=0, lat_coordinate=-114.2246266635263, long_coordinate=51.07431760032505),)
# (Attendance_Area(id=48, polygon_number=0, lat_coordinate=-114.2343480539441, long_coordinate=51.07430660143223),)
# (Attendance_Area(id=49, polygon_number=0, lat_coordinate=-114.2343480540452, long_coordinate=51.07430633893271),)
# (Attendance_Area(id=50, polygon_number=0, lat_coordinate=-114.2343407135355, long_coordinate=51.0670757907583),)
# (Attendance_Area(id=51, polygon_number=0, lat_coordinate=-114.2343406236226, long_coordinate=51.06698508472148),)
# (Attendance_Area(id=52, polygon_number=0, lat_coordinate=-114.2343404885262, long_coordinate=51.06684841526238),)
# (Attendance_Area(id=53, polygon_number=0, lat_coordinate=-114.2344144291688, long_coordinate=51.06684833623449),)
# (Attendance_Area(id=54, polygon_number=0, lat_coordinate=-114.2344086831208, long_coordinate=51.06047219502862),)
# (Attendance_Area(id=55, polygon_number=0, lat_coordinate=-114.2343347362246, long_coordinate=51.06042606958584),)
# (Attendance_Area(id=56, polygon_number=0, lat_coordinate=-114.2343342115512, long_coordinate=51.05984766274632),)
# (Attendance_Area(id=57, polygon_number=0, lat_coordinate=-114.2344081632251, long_coordinate=51.05989378728479),)
# (Attendance_Area(id=58, polygon_number=0, lat_coordinate=-114.2344097476136, long_coordinate=51.05738983312725),)
# (Attendance_Area(id=59, polygon_number=0, lat_coordinate=-114.2344119785207, long_coordinate=51.05462032796661),)
# (Attendance_Area(id=60, polygon_number=0, lat_coordinate=-114.2344122015228, long_coordinate=51.05434637976954),)
# (Attendance_Area(id=61, polygon_number=0, lat_coordinate=-114.2344127519259, long_coordinate=51.05366066509867),)
# (Attendance_Area(id=62, polygon_number=0, lat_coordinate=-114.2344132641389, long_coordinate=51.053030667908),)
# (Attendance_Area(id=63, polygon_number=0, lat_coordinate=-114.23441375111, long_coordinate=51.05242533314395),)
# (Attendance_Area(id=64, polygon_number=0, lat_coordinate=-114.2343398550717, long_coordinate=51.05242545974374),)
# (Attendance_Area(id=65, polygon_number=0, lat_coordinate=-114.2343086321757, long_coordinate=51.04519174631031),)
# (Attendance_Area(id=66, polygon_number=0, lat_coordinate=-114.2343125097618, long_coordinate=51.04347333896354),)
# (Attendance_Area(id=67, polygon_number=0, lat_coordinate=-114.2343208254967, long_coordinate=51.03793788788741),)
# (Attendance_Area(id=68, polygon_number=0, lat_coordinate=-114.2343255941719, long_coordinate=51.03770874554142),)
# (Attendance_Area(id=69, polygon_number=0, lat_coordinate=-114.2343971107423, long_coordinate=51.03770879181496),)
# (Attendance_Area(id=70, polygon_number=0, lat_coordinate=-114.2343953592985, long_coordinate=51.03684305714468),)
# (Attendance_Area(id=71, polygon_number=0, lat_coordinate=-114.2343825478433, long_coordinate=51.03055846525476),)
# (Attendance_Area(id=72, polygon_number=0, lat_coordinate=-114.2343086746428, long_coordinate=51.03055848573415),)
# (Attendance_Area(id=73, polygon_number=0, lat_coordinate=-114.2343074921954, long_coordinate=51.02925123147705),)
# (Attendance_Area(id=74, polygon_number=0, lat_coordinate=-114.2343071153821, long_coordinate=51.02866019241008),)
# (Attendance_Area(id=75, polygon_number=0, lat_coordinate=-114.2343066917353, long_coordinate=51.0280881325888),)
# (Attendance_Area(id=76, polygon_number=0, lat_coordinate=-114.2343062956043, long_coordinate=51.02758118559825),)
# (Attendance_Area(id=77, polygon_number=0, lat_coordinate=-114.2343059324667, long_coordinate=51.02710622591813),)
# (Attendance_Area(id=78, polygon_number=0, lat_coordinate=-114.2343055817476, long_coordinate=51.02664531809427),)
# (Attendance_Area(id=79, polygon_number=0, lat_coordinate=-114.2343052317476, long_coordinate=51.02617154136622),)
# (Attendance_Area(id=80, polygon_number=0, lat_coordinate=-114.2343048273932, long_coordinate=51.02565615641942),)
# (Attendance_Area(id=81, polygon_number=0, lat_coordinate=-114.234304230417, long_coordinate=51.02487407742851),)
# (Attendance_Area(id=82, polygon_number=0, lat_coordinate=-114.2343054748347, long_coordinate=51.02375882706972),)
# (Attendance_Area(id=83, polygon_number=0, lat_coordinate=-114.2343030565865, long_coordinate=51.02332235645406),)
# (Attendance_Area(id=84, polygon_number=0, lat_coordinate=-114.2343198571627, long_coordinate=51.0199966221705),)
# (Attendance_Area(id=85, polygon_number=0, lat_coordinate=-114.2343212048105, long_coordinate=51.01973011543119),)
# (Attendance_Area(id=86, polygon_number=0, lat_coordinate=-114.2343251746097, long_coordinate=51.01894550395179),)
# (Attendance_Area(id=87, polygon_number=0, lat_coordinate=-114.2343285833075, long_coordinate=51.01826958184652),)
# (Attendance_Area(id=88, polygon_number=0, lat_coordinate=-114.2343293382238, long_coordinate=51.01812018800762),)
# (Attendance_Area(id=89, polygon_number=0, lat_coordinate=-114.2343395355549, long_coordinate=51.01610150631016),)
# (Attendance_Area(id=90, polygon_number=0, lat_coordinate=-114.2343514872578, long_coordinate=51.01343995824364),)
# (Attendance_Area(id=91, polygon_number=0, lat_coordinate=-114.2343526119179, long_coordinate=51.01318948405537),)
# (Attendance_Area(id=92, polygon_number=0, lat_coordinate=-114.2343543280024, long_coordinate=51.01280753107772),)
# (Attendance_Area(id=93, polygon_number=0, lat_coordinate=-114.2343723358902, long_coordinate=51.0088791730473),)
# (Attendance_Area(id=94, polygon_number=0, lat_coordinate=-114.2343727036219, long_coordinate=51.00871264967122),)
# (Attendance_Area(id=95, polygon_number=0, lat_coordinate=-114.2225848889105, long_coordinate=51.00869734781865),)
# (Attendance_Area(id=96, polygon_number=0, lat_coordinate=-114.2111216499553, long_coordinate=51.00867394914835),)
# (Attendance_Area(id=97, polygon_number=0, lat_coordinate=-114.2107873657097, long_coordinate=51.00867387662978),)
# (Attendance_Area(id=98, polygon_number=0, lat_coordinate=-114.2037085575464, long_coordinate=51.00867230823352),)
# (Attendance_Area(id=99, polygon_number=0, lat_coordinate=-114.199894375666, long_coordinate=51.00867170820467),)
# (Attendance_Area(id=100, polygon_number=0, lat_coordinate=-114.1906742671298, long_coordinate=51.00866592596402),)
# (Attendance_Area(id=101, polygon_number=0, lat_coordinate=-114.1896466581531, long_coordinate=51.00866511894122),)
# (Attendance_Area(id=102, polygon_number=0, lat_coordinate=-114.1878599103058, long_coordinate=51.00866369102965),)
# (Attendance_Area(id=103, polygon_number=0, lat_coordinate=-114.1877180038211, long_coordinate=51.00866353792524),)
# (Attendance_Area(id=104, polygon_number=0, lat_coordinate=-114.183383721863, long_coordinate=51.00865879418008),)
# (Attendance_Area(id=105, polygon_number=0, lat_coordinate=-114.1760418077738, long_coordinate=51.0086503922258),)
# (Attendance_Area(id=106, polygon_number=0, lat_coordinate=-114.1702950949893, long_coordinate=51.00864470772996),)
# (Attendance_Area(id=107, polygon_number=0, lat_coordinate=-114.1655441270747, long_coordinate=51.00863992047793),)
# (Attendance_Area(id=108, polygon_number=0, lat_coordinate=-114.1653552639994, long_coordinate=51.00863972042939),)
# (Attendance_Area(id=109, polygon_number=0, lat_coordinate=-114.1648555653822, long_coordinate=51.00863919670182),)
# (Attendance_Area(id=110, polygon_number=0, lat_coordinate=-114.1647661860532, long_coordinate=51.00863910251995),)
# (Attendance_Area(id=111, polygon_number=0, lat_coordinate=-114.164549064577, long_coordinate=51.00863887718455),)
# (Attendance_Area(id=112, polygon_number=0, lat_coordinate=-114.1645190263498, long_coordinate=51.0086388385737),)
# (Attendance_Area(id=113, polygon_number=0, lat_coordinate=-114.1641702820034, long_coordinate=51.00863832042531),)
# (Attendance_Area(id=114, polygon_number=0, lat_coordinate=-114.1640847273525, long_coordinate=51.00863825181276),)
# (Attendance_Area(id=115, polygon_number=0, lat_coordinate=-114.1639993436957, long_coordinate=51.00863818289752),)
# (Attendance_Area(id=116, polygon_number=0, lat_coordinate=-114.1449039385552, long_coordinate=51.00861234550644),)
# (Attendance_Area(id=117, polygon_number=0, lat_coordinate=-114.1446389525856, long_coordinate=51.00861196182758),)
# (Attendance_Area(id=118, polygon_number=0, lat_coordinate=-114.141277175018, long_coordinate=51.0086070715581),)
# (Attendance_Area(id=119, polygon_number=0, lat_coordinate=-114.1412940790973, long_coordinate=51.00220411943353),)
# (Attendance_Area(id=120, polygon_number=0, lat_coordinate=-114.1412960081956, long_coordinate=51.00028657800117),)
# (Attendance_Area(id=121, polygon_number=0, lat_coordinate=-114.1412948694699, long_coordinate=50.99498102093567),)
# (Attendance_Area(id=122, polygon_number=0, lat_coordinate=-114.1412948224962, long_coordinate=50.99479995621333),)
# (Attendance_Area(id=123, polygon_number=0, lat_coordinate=-114.1412948090375, long_coordinate=50.99456894312672),)
# (Attendance_Area(id=124, polygon_number=0, lat_coordinate=-114.1412947597573, long_coordinate=50.99442980689886),)
# (Attendance_Area(id=125, polygon_number=0, lat_coordinate=-114.1412947119152, long_coordinate=50.99410209037826),)
# (Attendance_Area(id=126, polygon_number=0, lat_coordinate=-114.1352722758459, long_coordinate=50.9941104932061),)
# (Attendance_Area(id=127, polygon_number=0, lat_coordinate=-114.1352713396447, long_coordinate=50.99050141175548),)
# (Attendance_Area(id=128, polygon_number=0, lat_coordinate=-114.1179240076622, long_coordinate=50.99051588872476),)
# (Attendance_Area(id=129, polygon_number=0, lat_coordinate=-114.1179230139626, long_coordinate=50.99135758951294),)
# (Attendance_Area(id=130, polygon_number=0, lat_coordinate=-114.1179324955441, long_coordinate=50.99413270601115),)
# (Attendance_Area(id=131, polygon_number=0, lat_coordinate=-114.1145903952553, long_coordinate=50.99413268840902),)
# (Attendance_Area(id=132, polygon_number=0, lat_coordinate=-114.1144339923373, long_coordinate=50.99404230707334),)
# (Attendance_Area(id=133, polygon_number=0, lat_coordinate=-114.1135615232602, long_coordinate=50.99404233219603),)
# (Attendance_Area(id=134, polygon_number=0, lat_coordinate=-114.1134303583642, long_coordinate=50.99413275781014),)
# (Attendance_Area(id=135, polygon_number=0, lat_coordinate=-114.1091821607164, long_coordinate=50.99413289802537),)
# (Attendance_Area(id=136, polygon_number=0, lat_coordinate=-114.1091829316571, long_coordinate=50.9947850265174),)
# (Attendance_Area(id=137, polygon_number=0, lat_coordinate=-114.1091832170152, long_coordinate=50.99490663505522),)
# (Attendance_Area(id=138, polygon_number=0, lat_coordinate=-114.1091836938809, long_coordinate=50.99510985473415),)
# (Attendance_Area(id=139, polygon_number=0, lat_coordinate=-114.1091839887245, long_coordinate=50.99523550327823),)
# (Attendance_Area(id=140, polygon_number=0, lat_coordinate=-114.1091823414779, long_coordinate=50.99535186176394),)
# (Attendance_Area(id=141, polygon_number=0, lat_coordinate=-114.1091826410605, long_coordinate=50.99547953030935),)
# (Attendance_Area(id=142, polygon_number=0, lat_coordinate=-114.1091835063221, long_coordinate=50.99557568543459),)
# (Attendance_Area(id=143, polygon_number=0, lat_coordinate=-114.1091824778324, long_coordinate=50.99568315510798),)
# (Attendance_Area(id=144, polygon_number=0, lat_coordinate=-114.1091829934575, long_coordinate=50.99575719022477),)
# (Attendance_Area(id=145, polygon_number=0, lat_coordinate=-114.1091833794852, long_coordinate=50.99585248816538),)
# (Attendance_Area(id=146, polygon_number=0, lat_coordinate=-114.109183630205, long_coordinate=50.99597693569572),)
# (Attendance_Area(id=147, polygon_number=0, lat_coordinate=-114.1091819702278, long_coordinate=50.99615040824978),)
# (Attendance_Area(id=148, polygon_number=0, lat_coordinate=-114.109182436981, long_coordinate=50.99634931188627),)
# (Attendance_Area(id=149, polygon_number=0, lat_coordinate=-114.1091839333981, long_coordinate=50.99654625926983),)
# (Attendance_Area(id=150, polygon_number=0, lat_coordinate=-114.1091832649101, long_coordinate=50.9967021225381),)
# (Attendance_Area(id=151, polygon_number=0, lat_coordinate=-114.1091836857657, long_coordinate=50.99688146167416),)
# (Attendance_Area(id=152, polygon_number=0, lat_coordinate=-114.1091841571312, long_coordinate=50.99708232236304),)
# (Attendance_Area(id=153, polygon_number=0, lat_coordinate=-114.1091826868929, long_coordinate=50.99733666074282),)
# (Attendance_Area(id=154, polygon_number=0, lat_coordinate=-114.1091820550178, long_coordinate=50.99750752345276),)
# (Attendance_Area(id=155, polygon_number=0, lat_coordinate=-114.1091824100735, long_coordinate=50.99765882071356),)
# (Attendance_Area(id=156, polygon_number=0, lat_coordinate=-114.1091828406367, long_coordinate=50.99778158604391),)
# (Attendance_Area(id=157, polygon_number=0, lat_coordinate=-114.109221055035, long_coordinate=50.99783025891018),)
# (Attendance_Area(id=158, polygon_number=0, lat_coordinate=-114.1092173895126, long_coordinate=50.99807362724852),)
# (Attendance_Area(id=159, polygon_number=0, lat_coordinate=-114.1091623512339, long_coordinate=50.99814872470684),)
# (Attendance_Area(id=160, polygon_number=0, lat_coordinate=-114.1091636277909, long_coordinate=50.99847327387251),)
# (Attendance_Area(id=161, polygon_number=0, lat_coordinate=-114.1082014301308, long_coordinate=50.9982718784451),)
# (Attendance_Area(id=162, polygon_number=0, lat_coordinate=-114.1066354547549, long_coordinate=50.99791633499105),)
# (Attendance_Area(id=163, polygon_number=0, lat_coordinate=-114.105409037627, long_coordinate=50.9976080624439),)
# (Attendance_Area(id=164, polygon_number=0, lat_coordinate=-114.1038805805772, long_coordinate=50.99714535321647),)
# (Attendance_Area(id=165, polygon_number=0, lat_coordinate=-114.1025218115288, long_coordinate=50.996658676308),)
# (Attendance_Area(id=166, polygon_number=0, lat_coordinate=-114.1010307655539, long_coordinate=50.99602930470768),)
# (Attendance_Area(id=167, polygon_number=0, lat_coordinate=-114.0998038736991, long_coordinate=50.99545918589514),)
# (Attendance_Area(id=168, polygon_number=0, lat_coordinate=-114.0987846799722, long_coordinate=50.99500787317789),)
# (Attendance_Area(id=169, polygon_number=0, lat_coordinate=-114.0981241930847, long_coordinate=50.99475854140611),)
# (Attendance_Area(id=170, polygon_number=0, lat_coordinate=-114.0972185382018, long_coordinate=50.99448561126216),)
# (Attendance_Area(id=171, polygon_number=0, lat_coordinate=-114.096331897424, long_coordinate=50.99428405509054),)
# (Attendance_Area(id=172, polygon_number=0, lat_coordinate=-114.0958226708542, long_coordinate=50.99422497661414),)
# (Attendance_Area(id=173, polygon_number=0, lat_coordinate=-114.0953854757701, long_coordinate=50.99416972541955),)
# (Attendance_Area(id=174, polygon_number=0, lat_coordinate=-114.0950277286451, long_coordinate=50.99413941291871),)
# (Attendance_Area(id=175, polygon_number=0, lat_coordinate=-114.0947211278509, long_coordinate=50.99412250393252),)
# (Attendance_Area(id=176, polygon_number=0, lat_coordinate=-114.0946422352548, long_coordinate=50.99411815296879),)
# (Attendance_Area(id=177, polygon_number=0, lat_coordinate=-114.0926856671391, long_coordinate=50.99409506694772),)
# (Attendance_Area(id=178, polygon_number=0, lat_coordinate=-114.0897075337337, long_coordinate=50.99409417770882),)
# (Attendance_Area(id=179, polygon_number=0, lat_coordinate=-114.0878800130362, long_coordinate=50.99412938629669),)
# (Attendance_Area(id=180, polygon_number=0, lat_coordinate=-114.0871662900801, long_coordinate=50.99413932250838),)
# (Attendance_Area(id=181, polygon_number=0, lat_coordinate=-114.0832038197091, long_coordinate=50.99416182285782),)
# (Attendance_Area(id=182, polygon_number=0, lat_coordinate=-114.0815055857179, long_coordinate=50.99416349727365),)
# (Attendance_Area(id=183, polygon_number=0, lat_coordinate=-114.0787653197114, long_coordinate=50.99421933364801),)
# (Attendance_Area(id=184, polygon_number=0, lat_coordinate=-114.076431611116, long_coordinate=50.99419883252402),)
# (Attendance_Area(id=185, polygon_number=0, lat_coordinate=-114.0749057438118, long_coordinate=50.99422656815202),)
# (Attendance_Area(id=186, polygon_number=0, lat_coordinate=-114.0715355610429, long_coordinate=50.99423247935212),)
# (Attendance_Area(id=187, polygon_number=0, lat_coordinate=-114.0684310028158, long_coordinate=50.99423474979976),)
# (Attendance_Area(id=188, polygon_number=0, lat_coordinate=-114.0677115133822, long_coordinate=50.99422018747288),)
# (Attendance_Area(id=189, polygon_number=0, lat_coordinate=-114.066952456817, long_coordinate=50.9941806741917),)
# (Attendance_Area(id=190, polygon_number=0, lat_coordinate=-114.063819336931, long_coordinate=50.99397892703806),)
# (Attendance_Area(id=191, polygon_number=0, lat_coordinate=-114.0620138794978, long_coordinate=50.99388881900914),)
# (Attendance_Area(id=192, polygon_number=0, lat_coordinate=-114.0600792418702, long_coordinate=50.99385451248928),)
# (Attendance_Area(id=193, polygon_number=0, lat_coordinate=-114.058312409731, long_coordinate=50.99386953517171),)
# (Attendance_Area(id=194, polygon_number=0, lat_coordinate=-114.0567580783736, long_coordinate=50.99391268037931),)
# (Attendance_Area(id=195, polygon_number=0, lat_coordinate=-114.0521524670779, long_coordinate=50.99415854621056),)
# (Attendance_Area(id=196, polygon_number=0, lat_coordinate=-114.0483066482185, long_coordinate=50.99436672255238),)
# (Attendance_Area(id=197, polygon_number=0, lat_coordinate=-114.0467237777763, long_coordinate=50.99445236765054),)
# (Attendance_Area(id=198, polygon_number=0, lat_coordinate=-114.0449461374416, long_coordinate=50.99445657015623),)
# (Attendance_Area(id=199, polygon_number=0, lat_coordinate=-114.0438189870176, long_coordinate=50.99444519650739),)
# (Attendance_Area(id=200, polygon_number=0, lat_coordinate=-114.0425859379149, long_coordinate=50.99439451031867),)
# (Attendance_Area(id=201, polygon_number=0, lat_coordinate=-114.0414076392046, long_coordinate=50.99432052069902),)
# (Attendance_Area(id=202, polygon_number=0, lat_coordinate=-114.0400761024392, long_coordinate=50.99420563135788),)
# (Attendance_Area(id=203, polygon_number=0, lat_coordinate=-114.0388586673179, long_coordinate=50.99405704367619),)
# (Attendance_Area(id=204, polygon_number=0, lat_coordinate=-114.037922724843, long_coordinate=50.99388912666426),)
# (Attendance_Area(id=205, polygon_number=0, lat_coordinate=-114.037108523469, long_coordinate=50.99372596950072),)
# (Attendance_Area(id=206, polygon_number=0, lat_coordinate=-114.0361877744473, long_coordinate=50.99350996972225),)
# (Attendance_Area(id=207, polygon_number=0, lat_coordinate=-114.0349995361449, long_coordinate=50.99316415560143),)
# (Attendance_Area(id=208, polygon_number=0, lat_coordinate=-114.0348350402503, long_coordinate=50.99310952332537),)
# (Attendance_Area(id=209, polygon_number=0, lat_coordinate=-114.0344188630444, long_coordinate=50.99297130153449),)
# (Attendance_Area(id=210, polygon_number=0, lat_coordinate=-114.0334202710187, long_coordinate=50.99260203459107),)
# (Attendance_Area(id=211, polygon_number=0, lat_coordinate=-114.0325736164865, long_coordinate=50.99223398619024),)
# (Attendance_Area(id=212, polygon_number=0, lat_coordinate=-114.0314902211218, long_coordinate=50.99164407579796),)
# (Attendance_Area(id=213, polygon_number=0, lat_coordinate=-114.0307432841456, long_coordinate=50.99120395715349),)
# (Attendance_Area(id=214, polygon_number=0, lat_coordinate=-114.0298216306255, long_coordinate=50.99061945791942),)
# (Attendance_Area(id=215, polygon_number=0, lat_coordinate=-114.0287118601789, long_coordinate=50.98982938172262),)
# (Attendance_Area(id=216, polygon_number=0, lat_coordinate=-114.0278163492273, long_coordinate=50.98911584002075),)
# (Attendance_Area(id=217, polygon_number=0, lat_coordinate=-114.026767274414, long_coordinate=50.9882348013483),)
# (Attendance_Area(id=218, polygon_number=0, lat_coordinate=-114.0260519325654, long_coordinate=50.98763401508765),)
# (Attendance_Area(id=219, polygon_number=0, lat_coordinate=-114.0253921222725, long_coordinate=50.98707984973078),)
# (Attendance_Area(id=220, polygon_number=0, lat_coordinate=-114.0252580107227, long_coordinate=50.98696720935686),)
# (Attendance_Area(id=221, polygon_number=0, lat_coordinate=-114.0252546880171, long_coordinate=50.98697014345431),)
# (Attendance_Area(id=222, polygon_number=0, lat_coordinate=-114.0252230559165, long_coordinate=50.98699906065838),)
# (Attendance_Area(id=223, polygon_number=0, lat_coordinate=-114.0251864123068, long_coordinate=50.98703438867761),)
# (Attendance_Area(id=224, polygon_number=0, lat_coordinate=-114.0251439558032, long_coordinate=50.98706654452902),)
# (Attendance_Area(id=225, polygon_number=0, lat_coordinate=-114.0250978822168, long_coordinate=50.98709733468897),)
# (Attendance_Area(id=226, polygon_number=0, lat_coordinate=-114.0250496584311, long_coordinate=50.98713179313904),)
# (Attendance_Area(id=227, polygon_number=0, lat_coordinate=-114.0250115170617, long_coordinate=50.98716072966011),)
# (Attendance_Area(id=228, polygon_number=0, lat_coordinate=-114.0249747967973, long_coordinate=50.98718645649813),)
# (Attendance_Area(id=229, polygon_number=0, lat_coordinate=-114.0249330675804, long_coordinate=50.98721815363564),)
# (Attendance_Area(id=230, polygon_number=0, lat_coordinate=-114.0248985575811, long_coordinate=50.98724890528843),)
# (Attendance_Area(id=231, polygon_number=0, lat_coordinate=-114.0248691040012, long_coordinate=50.98727735446018),)
# (Attendance_Area(id=232, polygon_number=0, lat_coordinate=-114.0248417981891, long_coordinate=50.98730305228209),)
# (Attendance_Area(id=233, polygon_number=0, lat_coordinate=-114.0248000847254, long_coordinate=50.98733794974473),)
# (Attendance_Area(id=234, polygon_number=0, lat_coordinate=-114.0247540106429, long_coordinate=50.98736873976765),)
# (Attendance_Area(id=235, polygon_number=0, lat_coordinate=-114.0247064979873, long_coordinate=50.98740228096193),)
# (Attendance_Area(id=236, polygon_number=0, lat_coordinate=-114.0246741523994, long_coordinate=50.98743256461892),)
# (Attendance_Area(id=237, polygon_number=0, lat_coordinate=-114.0246338757887, long_coordinate=50.9874647117315),)
# (Attendance_Area(id=238, polygon_number=0, lat_coordinate=-114.0246029232458, long_coordinate=50.98748721887882),)
# (Attendance_Area(id=239, polygon_number=0, lat_coordinate=-114.0245684121076, long_coordinate=50.98751660397992),)
# (Attendance_Area(id=240, polygon_number=0, lat_coordinate=-114.0245382158494, long_coordinate=50.98754459474215),)
# (Attendance_Area(id=241, polygon_number=0, lat_coordinate=-114.0245051595684, long_coordinate=50.98757534597158),)
# (Attendance_Area(id=242, polygon_number=0, lat_coordinate=-114.0244648972181, long_coordinate=50.98761069249957),)
# (Attendance_Area(id=243, polygon_number=0, lat_coordinate=-114.0244310989957, long_coordinate=50.98763915145864),)
# (Attendance_Area(id=244, polygon_number=0, lat_coordinate=-114.024396618757, long_coordinate=50.98767356181194),)
# (Attendance_Area(id=245, polygon_number=0, lat_coordinate=-114.0243548737467, long_coordinate=50.98770388330078),)
# (Attendance_Area(id=246, polygon_number=0, lat_coordinate=-114.0243029999153, long_coordinate=50.98773332587962),)
# (Attendance_Area(id=247, polygon_number=0, lat_coordinate=-114.0242576370317, long_coordinate=50.98776365707575),)
# (Attendance_Area(id=248, polygon_number=0, lat_coordinate=-114.0242159212883, long_coordinate=50.98779854533765),)
# (Attendance_Area(id=249, polygon_number=0, lat_coordinate=-114.0241806550243, long_coordinate=50.98782564706456),)
# (Attendance_Area(id=250, polygon_number=0, lat_coordinate=-114.0241403765414, long_coordinate=50.98785824349616),)
# (Attendance_Area(id=251, polygon_number=0, lat_coordinate=-114.0241044129837, long_coordinate=50.9878867207865),)
# (Attendance_Area(id=252, polygon_number=0, lat_coordinate=-114.0240583374168, long_coordinate=50.98791933546601),)
# (Attendance_Area(id=253, polygon_number=0, lat_coordinate=-114.0240180753854, long_coordinate=50.98795377386595),)
# (Attendance_Area(id=254, polygon_number=0, lat_coordinate=-114.0239878785126, long_coordinate=50.98798176448388),)
# (Attendance_Area(id=255, polygon_number=0, lat_coordinate=-114.0239548360321, long_coordinate=50.98801296504349),)
# (Attendance_Area(id=256, polygon_number=0, lat_coordinate=-114.0239289832688, long_coordinate=50.98804094576524),)
# (Attendance_Area(id=257, polygon_number=0, lat_coordinate=-114.023895911053, long_coordinate=50.98806987278827),)
# (Attendance_Area(id=258, polygon_number=0, lat_coordinate=-114.0238541947635, long_coordinate=50.98810476002026),)
# (Attendance_Area(id=259, polygon_number=0, lat_coordinate=-114.0238168069611, long_coordinate=50.98813689726769),)
# (Attendance_Area(id=260, polygon_number=0, lat_coordinate=-114.0237693094451, long_coordinate=50.98817226210779),)
# (Attendance_Area(id=261, polygon_number=0, lat_coordinate=-114.0237326327596, long_coordinate=50.98820256525976),)
# (Attendance_Area(id=262, polygon_number=0, lat_coordinate=-114.0237002561271, long_coordinate=50.98822736485858),)
# (Attendance_Area(id=263, polygon_number=0, lat_coordinate=-114.0236621113637, long_coordinate=50.98825584245338),)
# (Attendance_Area(id=264, polygon_number=0, lat_coordinate=-114.0236275710683, long_coordinate=50.98828339335507),)
# (Attendance_Area(id=265, polygon_number=0, lat_coordinate=-114.023608908078, long_coordinate=50.98830311989527),)
# (Attendance_Area(id=266, polygon_number=0, lat_coordinate=-114.0235708238765, long_coordinate=50.9883389160604),)
# (Attendance_Area(id=267, polygon_number=0, lat_coordinate=-114.0235413678347, long_coordinate=50.98836828185406),)
# (Attendance_Area(id=268, polygon_number=0, lat_coordinate=-114.0235126244214, long_coordinate=50.98839581357344),)
# (Attendance_Area(id=269, polygon_number=0, lat_coordinate=-114.0234766453583, long_coordinate=50.98842337370925),)
# (Attendance_Area(id=270, polygon_number=0, lat_coordinate=-114.0234349282073, long_coordinate=50.98845780320764),)
# (Attendance_Area(id=271, polygon_number=0, lat_coordinate=-114.02339610148, long_coordinate=50.98849039818892),)
# (Attendance_Area(id=272, polygon_number=0, lat_coordinate=-114.0233572919722, long_coordinate=50.98852619352952),)
# (Attendance_Area(id=273, polygon_number=0, lat_coordinate=-114.0233206151991, long_coordinate=50.98855741351191),)
# (Attendance_Area(id=274, polygon_number=0, lat_coordinate=-114.0232817449475, long_coordinate=50.98858590011554),)
# (Attendance_Area(id=275, polygon_number=0, lat_coordinate=-114.0232421615063, long_coordinate=50.98861529481966),)
# (Attendance_Area(id=276, polygon_number=0, lat_coordinate=-114.0232004449815, long_coordinate=50.9886488162613),)
# (Attendance_Area(id=277, polygon_number=0, lat_coordinate=-114.0231688088111, long_coordinate=50.98867727442053),)
# (Attendance_Area(id=278, polygon_number=0, lat_coordinate=-114.0231372026756, long_coordinate=50.98870892395125),)
# (Attendance_Area(id=279, polygon_number=0, lat_coordinate=-114.0231106385132, long_coordinate=50.98873736311021),)
# (Attendance_Area(id=280, polygon_number=0, lat_coordinate=-114.023079744995, long_coordinate=50.98876719743938),)
# (Attendance_Area(id=281, polygon_number=0, lat_coordinate=-114.0230524375436, long_coordinate=50.98879334432775),)
# (Attendance_Area(id=282, polygon_number=0, lat_coordinate=-114.0230222544693, long_coordinate=50.98882271013161),)
# (Attendance_Area(id=283, polygon_number=0, lat_coordinate=-114.0230065886907, long_coordinate=50.98885568787622),)
# (Attendance_Area(id=284, polygon_number=0, lat_coordinate=-114.0229749823282, long_coordinate=50.98888734635187),)
# (Attendance_Area(id=285, polygon_number=0, lat_coordinate=-114.0229484179649, long_coordinate=50.98891578547306),)
# (Attendance_Area(id=286, polygon_number=0, lat_coordinate=-114.0229355971239, long_coordinate=50.98894417784084),)
# (Attendance_Area(id=287, polygon_number=0, lat_coordinate=-114.0229199011795, long_coordinate=50.98897395430421),)
# (Attendance_Area(id=288, polygon_number=0, lat_coordinate=-114.0229056871412, long_coordinate=50.9890078388224),)
# (Attendance_Area(id=289, polygon_number=0, lat_coordinate=-114.0228907168255, long_coordinate=50.98903898249092),)
# (Attendance_Area(id=290, polygon_number=0, lat_coordinate=-114.0228764892551, long_coordinate=50.98907150055518),)
# (Attendance_Area(id=291, polygon_number=0, lat_coordinate=-114.0228687849058, long_coordinate=50.98910627378553),)
# (Attendance_Area(id=292, polygon_number=0, lat_coordinate=-114.0228495152223, long_coordinate=50.98914200219841),)
# (Attendance_Area(id=293, polygon_number=0, lat_coordinate=-114.0228309591136, long_coordinate=50.98917773136759),)
# (Attendance_Area(id=294, polygon_number=0, lat_coordinate=-114.0228189095268, long_coordinate=50.98921069848937),)
# (Attendance_Area(id=295, polygon_number=0, lat_coordinate=-114.0228024720759, long_coordinate=50.98923909963823),)
# (Attendance_Area(id=296, polygon_number=0, lat_coordinate=-114.0227867747475, long_coordinate=50.98926933546219),)
# (Attendance_Area(id=297, polygon_number=0, lat_coordinate=-114.0227798114163, long_coordinate=50.98930502550253),)
# (Attendance_Area(id=298, polygon_number=0, lat_coordinate=-114.0227749849242, long_coordinate=50.9893384236208),)
# (Attendance_Area(id=299, polygon_number=0, lat_coordinate=-114.0227693982822, long_coordinate=50.98936404479456),)
# (Attendance_Area(id=300, polygon_number=0, lat_coordinate=-114.0227616500401, long_coordinate=50.98939379271587),)
# (Attendance_Area(id=301, polygon_number=0, lat_coordinate=-114.0227539451082, long_coordinate=50.98942765886409),)
# (Attendance_Area(id=302, polygon_number=0, lat_coordinate=-114.0227490706279, long_coordinate=50.98945327989782),)
# (Attendance_Area(id=303, polygon_number=0, lat_coordinate=-114.0227441828752, long_coordinate=50.98947798487111),)
# (Attendance_Area(id=304, polygon_number=0, lat_coordinate=-114.0227400965634, long_coordinate=50.98951046498237),)
# (Attendance_Area(id=305, polygon_number=0, lat_coordinate=-114.0227374632395, long_coordinate=50.98954613709508),)
# (Attendance_Area(id=306, polygon_number=0, lat_coordinate=-114.0227304704504, long_coordinate=50.98958000220334),)
# (Attendance_Area(id=307, polygon_number=0, lat_coordinate=-114.0227234930953, long_coordinate=50.98961340882714),)
# (Attendance_Area(id=308, polygon_number=0, lat_coordinate=-114.0227186648783, long_coordinate=50.98964633947118),)
# (Attendance_Area(id=309, polygon_number=0, lat_coordinate=-114.0227160003704, long_coordinate=50.98967653678916),)
# (Attendance_Area(id=310, polygon_number=0, lat_coordinate=-114.0227155325989, long_coordinate=50.98971037365737),)
# (Attendance_Area(id=311, polygon_number=0, lat_coordinate=-114.0227164859888, long_coordinate=50.98974054240333),)
# (Attendance_Area(id=312, polygon_number=0, lat_coordinate=-114.0227217545734, long_coordinate=50.98976933576648),)
# (Attendance_Area(id=313, polygon_number=0, lat_coordinate=-114.0227291883009, long_coordinate=50.98979537782383),)
# (Attendance_Area(id=314, polygon_number=0, lat_coordinate=-114.0227424338541, long_coordinate=50.989825049737),)
# (Attendance_Area(id=315, polygon_number=0, lat_coordinate=-114.0227492012721, long_coordinate=50.98985749267305),)
# (Attendance_Area(id=316, polygon_number=0, lat_coordinate=-114.0227523201949, long_coordinate=50.98988857795752),)
# (Attendance_Area(id=317, polygon_number=0, lat_coordinate=-114.0227482191612, long_coordinate=50.98992014200712),)
# (Attendance_Area(id=318, polygon_number=0, lat_coordinate=-114.0227448589407, long_coordinate=50.98995490538854),)
# (Attendance_Area(id=319, polygon_number=0, lat_coordinate=-114.0227479625031, long_coordinate=50.98998369917107),)
# (Attendance_Area(id=320, polygon_number=0, lat_coordinate=-114.0227510211887, long_coordinate=50.99000518334122),)
# (Attendance_Area(id=321, polygon_number=0, lat_coordinate=-114.0227563501498, long_coordinate=50.99004082693106),)
# (Attendance_Area(id=322, polygon_number=0, lat_coordinate=-114.0227703676472, long_coordinate=50.9900759923671),)
# (Attendance_Area(id=323, polygon_number=0, lat_coordinate=-114.0227720543272, long_coordinate=50.99014918533595),)
# (Attendance_Area(id=324, polygon_number=0, lat_coordinate=-114.0227768618758, long_coordinate=50.99016421537393),)
# (Attendance_Area(id=325, polygon_number=0, lat_coordinate=-114.0227944091411, long_coordinate=50.99019371653305),)
# (Attendance_Area(id=326, polygon_number=0, lat_coordinate=-114.0228171880324, long_coordinate=50.99022864651747),)
# (Attendance_Area(id=327, polygon_number=0, lat_coordinate=-114.0228281246352, long_coordinate=50.99025502859643),)
# (Attendance_Area(id=328, polygon_number=0, lat_coordinate=-114.0228385375913, long_coordinate=50.99028827090628),)
# (Attendance_Area(id=329, polygon_number=0, lat_coordinate=-114.0228482253288, long_coordinate=50.99032107195671),)
# (Attendance_Area(id=330, polygon_number=0, lat_coordinate=-114.0228576946276, long_coordinate=50.99034701471739),)
# (Attendance_Area(id=331, polygon_number=0, lat_coordinate=-114.0228686602201, long_coordinate=50.99037431464667),)
# (Attendance_Area(id=332, polygon_number=0, lat_coordinate=-114.0228738008247, long_coordinate=50.99040031129292),)
# (Attendance_Area(id=333, polygon_number=0, lat_coordinate=-114.0228751934885, long_coordinate=50.99042268667526),)
# (Attendance_Area(id=334, polygon_number=0, lat_coordinate=-114.0228753341924, long_coordinate=50.99045103064233),)
# (Attendance_Area(id=335, polygon_number=0, lat_coordinate=-114.0228752592897, long_coordinate=50.99047251632),)
# (Attendance_Area(id=336, polygon_number=0, lat_coordinate=-114.022883550887, long_coordinate=50.99050761993205),)
# (Attendance_Area(id=337, polygon_number=0, lat_coordinate=-114.0228908421217, long_coordinate=50.99053313070558),)
# (Attendance_Area(id=338, polygon_number=0, lat_coordinate=-114.0229034055719, long_coordinate=50.99056543764573),)
# (Attendance_Area(id=339, polygon_number=0, lat_coordinate=-114.022911421843, long_coordinate=50.99059093928577),)
# (Attendance_Area(id=340, polygon_number=0, lat_coordinate=-114.0229165337821, long_coordinate=50.99061647835301),)
# (Attendance_Area(id=341, polygon_number=0, lat_coordinate=-114.0229216151413, long_coordinate=50.99064065097387),)
# (Attendance_Area(id=342, polygon_number=0, lat_coordinate=-114.0229269730665, long_coordinate=50.99067395629499),)
# (Attendance_Area(id=343, polygon_number=0, lat_coordinate=-114.022934263153, long_coordinate=50.990699926445),)
# (Attendance_Area(id=344, polygon_number=0, lat_coordinate=-114.0229378496536, long_coordinate=50.99072273200704),)
# (Attendance_Area(id=345, polygon_number=0, lat_coordinate=-114.0229488877281, long_coordinate=50.99075231532618),)
# (Attendance_Area(id=346, polygon_number=0, lat_coordinate=-114.0229548274367, long_coordinate=50.99078104561348),)
# (Attendance_Area(id=347, polygon_number=0, lat_coordinate=-114.0229587455588, long_coordinate=50.99081482767558),)
# (Attendance_Area(id=348, polygon_number=0, lat_coordinate=-114.0229631745102, long_coordinate=50.99084174231596),)
# (Attendance_Area(id=349, polygon_number=0, lat_coordinate=-114.0229681835702, long_coordinate=50.99086363063572),)
# (Attendance_Area(id=350, polygon_number=0, lat_coordinate=-114.0229726542923, long_coordinate=50.99089146222862),)
# (Attendance_Area(id=351, polygon_number=0, lat_coordinate=-114.0229771411411, long_coordinate=50.99092021077928),)
# (Attendance_Area(id=352, polygon_number=0, lat_coordinate=-114.0229788944171, long_coordinate=50.99095446972591),)
# (Attendance_Area(id=353, polygon_number=0, lat_coordinate=-114.0229818558067, long_coordinate=50.99098049466176),)
# (Attendance_Area(id=354, polygon_number=0, lat_coordinate=-114.0229871979192, long_coordinate=50.9910133415008),)
# (Attendance_Area(id=355, polygon_number=0, lat_coordinate=-114.0229924835858, long_coordinate=50.99104436431669),)
# (Attendance_Area(id=356, polygon_number=0, lat_coordinate=-114.0229983640551, long_coordinate=50.9910712687802),)
# (Attendance_Area(id=357, polygon_number=0, lat_coordinate=-114.0230058423514, long_coordinate=50.9911031721655),)
# (Attendance_Area(id=358, polygon_number=0, lat_coordinate=-114.0230117097894, long_coordinate=50.99112961815004),)
# (Attendance_Area(id=359, polygon_number=0, lat_coordinate=-114.0230257987354, long_coordinate=50.99116419020701),)
# (Attendance_Area(id=360, polygon_number=0, lat_coordinate=-114.0230410817905, long_coordinate=50.99119098583552),)
# (Attendance_Area(id=361, polygon_number=0, lat_coordinate=-114.0230564645025, long_coordinate=50.99122051434638),)
# (Attendance_Area(id=362, polygon_number=0, lat_coordinate=-114.0230690875591, long_coordinate=50.99125464528677),)
# (Attendance_Area(id=363, polygon_number=0, lat_coordinate=-114.0230750549243, long_coordinate=50.99128429162226),)
# (Attendance_Area(id=364, polygon_number=0, lat_coordinate=-114.0230833031747, long_coordinate=50.99131756130138),)
# (Attendance_Area(id=365, polygon_number=0, lat_coordinate=-114.0230898681936, long_coordinate=50.99134308209114),)
# (Attendance_Area(id=366, polygon_number=0, lat_coordinate=-114.0230978994003, long_coordinate=50.99136950067324),)
# (Attendance_Area(id=367, polygon_number=0, lat_coordinate=-114.0231148091224, long_coordinate=50.9914017527879),)
# (Attendance_Area(id=368, polygon_number=0, lat_coordinate=-114.0231359895717, long_coordinate=50.99143167569178),)
# (Attendance_Area(id=369, polygon_number=0, lat_coordinate=-114.0231609183196, long_coordinate=50.99146566034655),)
# (Attendance_Area(id=370, polygon_number=0, lat_coordinate=-114.0231740940886, long_coordinate=50.9914938497955),)
# (Attendance_Area(id=371, polygon_number=0, lat_coordinate=-114.0231729270081, long_coordinate=50.99152722831301),)
# (Attendance_Area(id=372, polygon_number=0, lat_coordinate=-114.0231751620868, long_coordinate=50.99155326237527),)
# (Attendance_Area(id=373, polygon_number=0, lat_coordinate=-114.023181957543, long_coordinate=50.99158654941489),)
# (Attendance_Area(id=374, polygon_number=0, lat_coordinate=-114.0231916009507, long_coordinate=50.99161797589556),)
# (Attendance_Area(id=375, polygon_number=0, lat_coordinate=-114.0232012892145, long_coordinate=50.99165077780826),)
# (Attendance_Area(id=376, polygon_number=0, lat_coordinate=-114.0232100904103, long_coordinate=50.99167855369036),)
# (Attendance_Area(id=377, polygon_number=0, lat_coordinate=-114.0232219438309, long_coordinate=50.99171132820144),)
# (Attendance_Area(id=378, polygon_number=0, lat_coordinate=-114.0232387365609, long_coordinate=50.99173993045441),)
# (Attendance_Area(id=379, polygon_number=0, lat_coordinate=-114.023258608818, long_coordinate=50.99177397092997),)
# (Attendance_Area(id=380, polygon_number=0, lat_coordinate=-114.0232702001307, long_coordinate=50.99179806132646),)
# (Attendance_Area(id=381, polygon_number=0, lat_coordinate=-114.0232855124782, long_coordinate=50.9918257648856),)
# (Attendance_Area(id=382, polygon_number=0, lat_coordinate=-114.0232957230322, long_coordinate=50.99185169846639),)
# (Attendance_Area(id=383, polygon_number=0, lat_coordinate=-114.0233111208281, long_coordinate=50.99188214389868),)
# (Attendance_Area(id=384, polygon_number=0, lat_coordinate=-114.0233229164793, long_coordinate=50.99191309347726),)
# (Attendance_Area(id=385, polygon_number=0, lat_coordinate=-114.0233260069573, long_coordinate=50.9919432267198),)
# (Attendance_Area(id=386, polygon_number=0, lat_coordinate=-114.0233234015242, long_coordinate=50.99197708288261),)
# (Attendance_Area(id=387, polygon_number=0, lat_coordinate=-114.0233432597046, long_coordinate=50.99201113233504),)
# (Attendance_Area(id=388, polygon_number=0, lat_coordinate=-114.0233498814376, long_coordinate=50.99203848701813),)
# (Attendance_Area(id=389, polygon_number=0, lat_coordinate=-114.0233542091843, long_coordinate=50.9920617428037),)
# (Attendance_Area(id=390, polygon_number=0, lat_coordinate=-114.0233842239161, long_coordinate=50.99209613272993),)
# (Attendance_Area(id=391, polygon_number=0, lat_coordinate=-114.0234040098209, long_coordinate=50.99212789877293),)
# (Attendance_Area(id=392, polygon_number=0, lat_coordinate=-114.0234172440472, long_coordinate=50.99215836260264),)
# (Attendance_Area(id=393, polygon_number=0, lat_coordinate=-114.0234275997275, long_coordinate=50.99218933043755),)
# (Attendance_Area(id=394, polygon_number=0, lat_coordinate=-114.0234488675809, long_coordinate=50.99222198616696),)
# (Attendance_Area(id=395, polygon_number=0, lat_coordinate=-114.0234605606602, long_coordinate=50.99224973537667),)
# (Attendance_Area(id=396, polygon_number=0, lat_coordinate=-114.0234743750206, long_coordinate=50.99227516478675),)
# (Attendance_Area(id=397, polygon_number=0, lat_coordinate=-114.0234942782912, long_coordinate=50.99231058964423),)
# (Attendance_Area(id=398, polygon_number=0, lat_coordinate=-114.0235076272408, long_coordinate=50.99234517077459),)
# (Attendance_Area(id=399, polygon_number=0, lat_coordinate=-114.023518709487, long_coordinate=50.99237612047464),)
# (Attendance_Area(id=400, polygon_number=0, lat_coordinate=-114.0235320729504, long_coordinate=50.99241116097842),)
# (Attendance_Area(id=401, polygon_number=0, lat_coordinate=-114.0235437369463, long_coordinate=50.99243754373293),)
# (Attendance_Area(id=402, polygon_number=0, lat_coordinate=-114.0235568263623, long_coordinate=50.99246298226841),)
# (Attendance_Area(id=403, polygon_number=0, lat_coordinate=-114.0235758571166, long_coordinate=50.99249384046127),)
# (Attendance_Area(id=404, polygon_number=0, lat_coordinate=-114.0236014987541, long_coordinate=50.99252736729049),)
# (Attendance_Area(id=405, polygon_number=0, lat_coordinate=-114.023631356146, long_coordinate=50.99255672288643),)
# (Attendance_Area(id=406, polygon_number=0, lat_coordinate=-114.0236654985983, long_coordinate=50.99258373935622),)
# (Attendance_Area(id=407, polygon_number=0, lat_coordinate=-114.0236996847582, long_coordinate=50.99261258972904),)
# (Attendance_Area(id=408, polygon_number=0, lat_coordinate=-114.0237449424893, long_coordinate=50.99264816222274),)
# (Attendance_Area(id=409, polygon_number=0, lat_coordinate=-114.0237783313072, long_coordinate=50.99267473921038),)
# (Attendance_Area(id=410, polygon_number=0, lat_coordinate=-114.0238097707368, long_coordinate=50.99270819289415),)
# (Attendance_Area(id=411, polygon_number=0, lat_coordinate=-114.0238419948347, long_coordinate=50.99274392083215),)
# (Attendance_Area(id=412, polygon_number=0, lat_coordinate=-114.0238667218633, long_coordinate=50.99277105692968),)
# (Attendance_Area(id=413, polygon_number=0, lat_coordinate=-114.0238958096626, long_coordinate=50.99279904526347),)
# (Attendance_Area(id=414, polygon_number=0, lat_coordinate=-114.0239286010893, long_coordinate=50.99282973876532),)
# (Attendance_Area(id=415, polygon_number=0, lat_coordinate=-114.0239629179159, long_coordinate=50.99286270636767),)
# (Attendance_Area(id=416, polygon_number=0, lat_coordinate=-114.0239987167023, long_coordinate=50.99289656364695),)
# (Attendance_Area(id=417, polygon_number=0, lat_coordinate=-114.0240287037182, long_coordinate=50.99293048593814),)
# (Attendance_Area(id=418, polygon_number=0, lat_coordinate=-114.0240659702794, long_coordinate=50.99296524187587),)
# ...
# (Attendance_Area(id=5481, polygon_number=0, lat_coordinate=-114.1704383226229, long_coordinate=51.0688192644521),)
# (Attendance_Area(id=5482, polygon_number=0, lat_coordinate=-114.1704833037668, long_coordinate=51.06882151820545),)
# (Attendance_Area(id=5483, polygon_number=0, lat_coordinate=-114.1705326341733, long_coordinate=51.06882697582035),)
# (Attendance_Area(id=5484, polygon_number=0, lat_coordinate=-114.1705805243268, long_coordinate=51.06883653482108),)
# (Attendance_Area(id=5485, polygon_number=0, lat_coordinate=-114.170626972583, long_coordinate=51.06884974482767),)
# (Attendance_Area(id=5486, polygon_number=0, lat_coordinate=-114.1706777661795, long_coordinate=51.06886159102624),)
# (Attendance_Area(id=5487, polygon_number=0, lat_coordinate=-114.1707271050186, long_coordinate=51.06886932294189),)
# (Attendance_Area(id=5488, polygon_number=0, lat_coordinate=-114.1707822316462, long_coordinate=51.06887567994632),)
# (Attendance_Area(id=5489, polygon_number=0, lat_coordinate=-114.1708221418646, long_coordinate=51.06888022436235),)
# (Attendance_Area(id=5490, polygon_number=0, lat_coordinate=-114.1708714706519, long_coordinate=51.06888521437201),)
# (Attendance_Area(id=5491, polygon_number=0, lat_coordinate=-114.1709215355601, long_coordinate=51.06889249565905),)
# (Attendance_Area(id=5492, polygon_number=0, lat_coordinate=-114.1709781293642, long_coordinate=51.06890204986158),)
# (Attendance_Area(id=5493, polygon_number=0, lat_coordinate=-114.1710311025608, long_coordinate=51.0689202852972),)
# (Attendance_Area(id=5494, polygon_number=0, lat_coordinate=-114.1710826338168, long_coordinate=51.06893440463576),)
# (Attendance_Area(id=5495, polygon_number=0, lat_coordinate=-114.1711247137358, long_coordinate=51.06894305496674),)
# (Attendance_Area(id=5496, polygon_number=0, lat_coordinate=-114.1711639039932, long_coordinate=51.06895353352458),)
# (Attendance_Area(id=5497, polygon_number=0, lat_coordinate=-114.1712110780045, long_coordinate=51.06897040104582),)
# (Attendance_Area(id=5498, polygon_number=0, lat_coordinate=-114.1712539084369, long_coordinate=51.06898909173051),)
# (Attendance_Area(id=5499, polygon_number=0, lat_coordinate=-114.1713010687787, long_coordinate=51.06900185094064),)
# (Attendance_Area(id=5500, polygon_number=0, lat_coordinate=-114.1713518694217, long_coordinate=51.06901551365505),)
# (Attendance_Area(id=5501, polygon_number=0, lat_coordinate=-114.1714084787915, long_coordinate=51.06903694302516),)
# (Attendance_Area(id=5502, polygon_number=0, lat_coordinate=-114.171455648414, long_coordinate=51.06904832763359),)
# (Attendance_Area(id=5503, polygon_number=0, lat_coordinate=-114.1715042813231, long_coordinate=51.06906610085677),)
# (Attendance_Area(id=5504, polygon_number=0, lat_coordinate=-114.1715608975747, long_coordinate=51.06908935595171),)
# (Attendance_Area(id=5505, polygon_number=0, lat_coordinate=-114.1716087961479, long_coordinate=51.0691053052991),)
# (Attendance_Area(id=5506, polygon_number=0, lat_coordinate=-114.1716624940996, long_coordinate=51.0691226215356),)
# (Attendance_Area(id=5507, polygon_number=0, lat_coordinate=-114.1717147577729, long_coordinate=51.06914176566291),)
# (Attendance_Area(id=5508, polygon_number=0, lat_coordinate=-114.1717583073269, long_coordinate=51.06916228810661),)
# (Attendance_Area(id=5509, polygon_number=0, lat_coordinate=-114.1717873525226, long_coordinate=51.06917642219057),)
# (Attendance_Area(id=5510, polygon_number=0, lat_coordinate=-114.1718417768715, long_coordinate=51.06919373817606),)
# (Attendance_Area(id=5511, polygon_number=0, lat_coordinate=-114.1718882183681, long_coordinate=51.06920878159069),)
# (Attendance_Area(id=5512, polygon_number=0, lat_coordinate=-114.1719274234963, long_coordinate=51.06922701798452),)
# (Attendance_Area(id=5513, polygon_number=0, lat_coordinate=-114.1719796936865, long_coordinate=51.06925209428912),)
# (Attendance_Area(id=5514, polygon_number=0, lat_coordinate=-114.1720246968386, long_coordinate=51.06927169844396),)
# (Attendance_Area(id=5515, polygon_number=0, lat_coordinate=-114.1720718799524, long_coordinate=51.06929084898861),)
# (Attendance_Area(id=5516, polygon_number=0, lat_coordinate=-114.1721226811335, long_coordinate=51.06931181909685),)
# (Attendance_Area(id=5517, polygon_number=0, lat_coordinate=-114.1721735063523, long_coordinate=51.06933964020052),)
# (Attendance_Area(id=5518, polygon_number=0, lat_coordinate=-114.1721945773673, long_coordinate=51.06936610092196),)
# (Attendance_Area(id=5519, polygon_number=0, lat_coordinate=-114.1721997101736, long_coordinate=51.06939623583682),)
# (Attendance_Area(id=5520, polygon_number=0, lat_coordinate=-114.172200493809, long_coordinate=51.06943092504886),)
# (Attendance_Area(id=5521, polygon_number=0, lat_coordinate=-114.1721969043681, long_coordinate=51.06945603857751),)
# (Attendance_Area(id=5522, polygon_number=0, lat_coordinate=-114.1722049437621, long_coordinate=51.06948890118097),)
# (Attendance_Area(id=5523, polygon_number=0, lat_coordinate=-114.1722223938777, long_coordinate=51.0695158266044),)
# (Attendance_Area(id=5524, polygon_number=0, lat_coordinate=-114.172253629091, long_coordinate=51.06954365765316),)
# (Attendance_Area(id=5525, polygon_number=0, lat_coordinate=-114.1722993605914, long_coordinate=51.06956371820417),)
# (Attendance_Area(id=5526, polygon_number=0, lat_coordinate=-114.1723530437979, long_coordinate=51.06956916863497),)
# (Attendance_Area(id=5527, polygon_number=0, lat_coordinate=-114.1724030890127, long_coordinate=51.06956320658453),)
# (Attendance_Area(id=5528, polygon_number=0, lat_coordinate=-114.1724487787357, long_coordinate=51.06955587641227),)
# (Attendance_Area(id=5529, polygon_number=0, lat_coordinate=-114.1724893969993, long_coordinate=51.06955493639447),)
# (Attendance_Area(id=5530, polygon_number=0, lat_coordinate=-114.172541631644, long_coordinate=51.06956221288679),)
# (Attendance_Area(id=5531, polygon_number=0, lat_coordinate=-114.172586635609, long_coordinate=51.06958227439929),)
# (Attendance_Area(id=5532, polygon_number=0, lat_coordinate=-114.1726236796719, long_coordinate=51.06961009677292),)
# (Attendance_Area(id=5533, polygon_number=0, lat_coordinate=-114.1726737876297, long_coordinate=51.06964476797185),)
# (Attendance_Area(id=5534, polygon_number=0, lat_coordinate=-114.1727086531907, long_coordinate=51.06967761878006),)
# (Attendance_Area(id=5535, polygon_number=0, lat_coordinate=-114.1727275480801, long_coordinate=51.06969815031412),)
# (Attendance_Area(id=5536, polygon_number=0, lat_coordinate=-114.1727486158535, long_coordinate=51.06971594576453),)
# (Attendance_Area(id=5537, polygon_number=0, lat_coordinate=-114.1727878357222, long_coordinate=51.06974559876957),)
# (Attendance_Area(id=5538, polygon_number=0, lat_coordinate=-114.1728350155428, long_coordinate=51.06976748187967),)
# (Attendance_Area(id=5539, polygon_number=0, lat_coordinate=-114.1728749341724, long_coordinate=51.0697820670802),)
# (Attendance_Area(id=5540, polygon_number=0, lat_coordinate=-114.1729271933287, long_coordinate=51.06980349405525),)
# (Attendance_Area(id=5541, polygon_number=0, lat_coordinate=-114.1729685752289, long_coordinate=51.06982401026312),)
# (Attendance_Area(id=5542, polygon_number=0, lat_coordinate=-114.1730201309039, long_coordinate=51.06985228749189),)
# (Attendance_Area(id=5543, polygon_number=0, lat_coordinate=-114.1730767403539, long_coordinate=51.06987325757702),)
# (Attendance_Area(id=5544, polygon_number=0, lat_coordinate=-114.1731304434155, long_coordinate=51.0698919404639),)
# (Attendance_Area(id=5545, polygon_number=0, lat_coordinate=-114.1731819913902, long_coordinate=51.06991428442863),)
# (Attendance_Area(id=5546, polygon_number=0, lat_coordinate=-114.1732320632917, long_coordinate=51.06993068836456),)
# (Attendance_Area(id=5547, polygon_number=0, lat_coordinate=-114.1732792387619, long_coordinate=51.0699470965722),)
# (Attendance_Area(id=5548, polygon_number=0, lat_coordinate=-114.1733249717085, long_coordinate=51.06996349880896),)
# (Attendance_Area(id=5549, polygon_number=0, lat_coordinate=-114.1733714260323, long_coordinate=51.0699858412524),)
# (Attendance_Area(id=5550, polygon_number=0, lat_coordinate=-114.1734186050343, long_coordinate=51.07000316634824),)
# (Attendance_Area(id=5551, polygon_number=0, lat_coordinate=-114.1734599859542, long_coordinate=51.07001911561417),)
# (Attendance_Area(id=5552, polygon_number=0, lat_coordinate=-114.1735165989046, long_coordinate=51.07004511162344),)
# (Attendance_Area(id=5553, polygon_number=0, lat_coordinate=-114.1735688777002, long_coordinate=51.07007201211166),)
# (Attendance_Area(id=5554, polygon_number=0, lat_coordinate=-114.1736175283841, long_coordinate=51.07010165982399),)
# (Attendance_Area(id=5555, polygon_number=0, lat_coordinate=-114.1736668987657, long_coordinate=51.07013678027657),)
# (Attendance_Area(id=5556, polygon_number=0, lat_coordinate=-114.173706845837, long_coordinate=51.07016643189134),)
# (Attendance_Area(id=5557, polygon_number=0, lat_coordinate=-114.1737388066667, long_coordinate=51.07019335350263),)
# (Attendance_Area(id=5558, polygon_number=0, lat_coordinate=-114.1737693263921, long_coordinate=51.07022026825747),)
# (Attendance_Area(id=5559, polygon_number=0, lat_coordinate=-114.1738179767623, long_coordinate=51.07025356570541),)
# (Attendance_Area(id=5560, polygon_number=0, lat_coordinate=-114.1738746004359, long_coordinate=51.070282293495),)
# (Attendance_Area(id=5561, polygon_number=0, lat_coordinate=-114.1739159866181, long_coordinate=51.07030372630944),)
# (Attendance_Area(id=5562, polygon_number=0, lat_coordinate=-114.1739646411706, long_coordinate=51.07033428183059),)
# (Attendance_Area(id=5563, polygon_number=0, lat_coordinate=-114.1740031332218, long_coordinate=51.07036393550858),)
# (Attendance_Area(id=5564, polygon_number=0, lat_coordinate=-114.1740372814268, long_coordinate=51.07039952794511),)
# (Attendance_Area(id=5565, polygon_number=0, lat_coordinate=-114.1740569151402, long_coordinate=51.07042279103169),)
# (Attendance_Area(id=5566, polygon_number=0, lat_coordinate=-114.1740750981066, long_coordinate=51.07045109050826),)
# (Attendance_Area(id=5567, polygon_number=0, lat_coordinate=-114.1740998052238, long_coordinate=51.0704802963164),)
# (Attendance_Area(id=5568, polygon_number=0, lat_coordinate=-114.1741259762951, long_coordinate=51.07051177523221),)
# (Attendance_Area(id=5569, polygon_number=0, lat_coordinate=-114.1741543128354, long_coordinate=51.07054235104669),)
# (Attendance_Area(id=5570, polygon_number=0, lat_coordinate=-114.1741870064383, long_coordinate=51.07057428769589),)
# (Attendance_Area(id=5571, polygon_number=0, lat_coordinate=-114.1742305921244, long_coordinate=51.07060758352711),)
# (Attendance_Area(id=5572, polygon_number=0, lat_coordinate=-114.1742690771574, long_coordinate=51.07063906203626),)
# (Attendance_Area(id=5573, polygon_number=0, lat_coordinate=-114.1743061331392, long_coordinate=51.07067374209822),)
# (Attendance_Area(id=5574, polygon_number=0, lat_coordinate=-114.174332289582, long_coordinate=51.07069746287617),)
# (Attendance_Area(id=5575, polygon_number=0, lat_coordinate=-114.1743620748762, long_coordinate=51.07072620347893),)
# (Attendance_Area(id=5576, polygon_number=0, lat_coordinate=-114.1744020334974, long_coordinate=51.07075905427127),)
# (Attendance_Area(id=5577, polygon_number=0, lat_coordinate=-114.1744390788224, long_coordinate=51.07079464316508),)
# (Attendance_Area(id=5578, polygon_number=0, lat_coordinate=-114.1744746853132, long_coordinate=51.07082703386087),)
# (Attendance_Area(id=5579, polygon_number=0, lat_coordinate=-114.1745080955429, long_coordinate=51.07085211919681),)
# (Attendance_Area(id=5580, polygon_number=0, lat_coordinate=-114.1745647301504, long_coordinate=51.07088723831112),)
# (Attendance_Area(id=5581, polygon_number=0, lat_coordinate=-114.1746155568299, long_coordinate=51.07091459897131),)
# (Attendance_Area(id=5582, polygon_number=0, lat_coordinate=-114.1746591110556, long_coordinate=51.07093557879736),)
# (Attendance_Area(id=5583, polygon_number=0, lat_coordinate=-114.1747099412622, long_coordinate=51.07096384737081),)
# (Attendance_Area(id=5584, polygon_number=0, lat_coordinate=-114.1747535117248, long_coordinate=51.07099669264401),)
# (Attendance_Area(id=5585, polygon_number=0, lat_coordinate=-114.1747934651583, long_coordinate=51.07103181860231),)
# (Attendance_Area(id=5586, polygon_number=0, lat_coordinate=-114.1748370414092, long_coordinate=51.07106238045122),)
# (Attendance_Area(id=5587, polygon_number=0, lat_coordinate=-114.1748806142991, long_coordinate=51.07109203522803),)
# (Attendance_Area(id=5588, polygon_number=0, lat_coordinate=-114.1749125798702, long_coordinate=51.07111986446737),)
# (Attendance_Area(id=5589, polygon_number=0, lat_coordinate=-114.1749416432443, long_coordinate=51.07114997243549),)
# (Attendance_Area(id=5590, polygon_number=0, lat_coordinate=-114.1749757989128, long_coordinate=51.07117963137995),)
# (Attendance_Area(id=5591, polygon_number=0, lat_coordinate=-114.1750070385932, long_coordinate=51.07120791116468),)
# (Attendance_Area(id=5592, polygon_number=0, lat_coordinate=-114.1750390026245, long_coordinate=51.07123529088644),)
# (Attendance_Area(id=5593, polygon_number=0, lat_coordinate=-114.175073859281, long_coordinate=51.07126539823732),)
# (Attendance_Area(id=5594, polygon_number=0, lat_coordinate=-114.1751247024832, long_coordinate=51.07129732541793),)
# (Attendance_Area(id=5595, polygon_number=0, lat_coordinate=-114.1751660943584, long_coordinate=51.0713274328395),)
# (Attendance_Area(id=5596, polygon_number=0, lat_coordinate=-114.1751987840184, long_coordinate=51.07135799378373),)
# (Attendance_Area(id=5597, polygon_number=0, lat_coordinate=-114.1752300326082, long_coordinate=51.07138856496959),)
# (Attendance_Area(id=5598, polygon_number=0, lat_coordinate=-114.1752540149467, long_coordinate=51.07141822200006),)
# (Attendance_Area(id=5599, polygon_number=0, lat_coordinate=-114.1752845427998, long_coordinate=51.07145061916074),)
# (Attendance_Area(id=5600, polygon_number=0, lat_coordinate=-114.1753128724996, long_coordinate=51.07147525340748),)
# (Attendance_Area(id=5601, polygon_number=0, lat_coordinate=-114.1753520990574, long_coordinate=51.07151037936347),)
# (Attendance_Area(id=5602, polygon_number=0, lat_coordinate=-114.1753884223815, long_coordinate=51.07153957735869),)
# (Attendance_Area(id=5603, polygon_number=0, lat_coordinate=-114.1754058501669, long_coordinate=51.0715523525439),)
# (Attendance_Area(id=5604, polygon_number=0, lat_coordinate=-114.1754523328226, long_coordinate=51.07158565255786),)
# (Attendance_Area(id=5605, polygon_number=0, lat_coordinate=-114.1754857540275, long_coordinate=51.0716171283732),)
# (Attendance_Area(id=5606, polygon_number=0, lat_coordinate=-114.175514096041, long_coordinate=51.0716449628854),)
# (Attendance_Area(id=5607, polygon_number=0, lat_coordinate=-114.1755446172873, long_coordinate=51.07167552608811),)
# (Attendance_Area(id=5608, polygon_number=0, lat_coordinate=-114.1755729609556, long_coordinate=51.07170792735103),)
# (Attendance_Area(id=5609, polygon_number=0, lat_coordinate=-114.1756107356456, long_coordinate=51.07174351387413),)
# (Attendance_Area(id=5610, polygon_number=0, lat_coordinate=-114.1756506905158, long_coordinate=51.07177453124071),)
# (Attendance_Area(id=5611, polygon_number=0, lat_coordinate=-114.1756732257082, long_coordinate=51.07179871563051),)
# (Attendance_Area(id=5612, polygon_number=0, lat_coordinate=-114.1756979328142, long_coordinate=51.07182746262033),)
# (Attendance_Area(id=5613, polygon_number=0, lat_coordinate=-114.1757349893564, long_coordinate=51.07186213413173),)
# (Attendance_Area(id=5614, polygon_number=0, lat_coordinate=-114.1757698538485, long_coordinate=51.07189406616968),)
# (Attendance_Area(id=5615, polygon_number=0, lat_coordinate=-114.1758112678584, long_coordinate=51.07192599823603),)
# (Attendance_Area(id=5616, polygon_number=0, lat_coordinate=-114.1758635530483, long_coordinate=51.07196158083254),)
# (Attendance_Area(id=5617, polygon_number=0, lat_coordinate=-114.1759071338907, long_coordinate=51.07199670094831),)
# (Attendance_Area(id=5618, polygon_number=0, lat_coordinate=-114.1759081958474, long_coordinate=51.07199754347967),)

# %%
#session.commit()
# Out:
# 2023-11-20 07:41:03,834 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# #### Rollback

# %%
#session.rollback()

# %% [markdown]
# #### Close session

# %%
session.close()
